# %%
from ase.io import read, write
import numpy as np
import pandas as pd
import os
from ase.units import Hartree, kcal, mol
kcal_mol = kcal/mol
Hart_to_kcalmol = Hartree/kcal_mol

# %% [markdown]
# # [W4-11 Dataset](http://www.thch.uni-bonn.de/tc.old/downloads/GMTKN/GMTKN55/W4-11.html)
#
# Prepare trajectory with reference atomization energies and CCSD(T) total energies.

# %%
w4p = '/home/awills/Documents/Research/datasets/W4-11'
w4cp = '/home/awills/Documents/Research/swxcd/aegis/w411'
w4ref = pd.read_csv(os.path.join(w4p, 'ref.dat'), delimiter='\t', skiprows=1, index_col=False, header=None)[[1, 11]]
w4ref.columns = ['name', 'en'] #energy in kcal/mol
w4ref['en_H'] = -w4ref['en'].values/Hart_to_kcalmol
w4ref['name'] = w4ref['name'].str.strip()

w4cc = pd.read_csv(os.path.join(w4cp, 'progress'), delimiter='\t')
w4cc.columns = [i.strip() for i in w4cc.columns]
w4cc['atoms.symbols'] = w4cc['atoms.symbols'].str.strip()

sdirs = sorted([i for i in os.listdir(w4p) if os.path.isdir(os.path.join(w4p, i))])
atoms = []
for idir in sdirs:
    at = read(os.path.join(w4p,idir,'struc.xyz'), ':')[0]
    sym = str(at.symbols)
    cce = w4cc[w4cc['atoms.symbols'] == sym]['etot  (Har)'].values
    eref = w4ref[w4ref['name'] == idir]['en_H'].values
    print(idir, at, eref, cce)
    try:
        at.info['atomization'] = eref[0]
        at.info['energy'] = cce[0]
        atoms.append(at)
    except:
        #energy not in dataframe, so not one of the AEs. probably single atom
        continue
write(os.path.join(w4p, 'w411.traj'), atoms)
# Out:
# acetaldehyde Atoms(symbols='COHCH3', pbc=False) [-1.08024505] [-153.65854659]
# acetic Atoms(symbols='C2O2H4', pbc=False) [-1.28128265] [-228.85096309]
# al Atoms(symbols='Al', pbc=False) [] []
# alcl Atoms(symbols='AlCl', pbc=False) [-0.19540422] [-702.02772785]
# alcl3 Atoms(symbols='AlCl3', pbc=False) [-0.49824108] [-1621.83173868]
# alf Atoms(symbols='AlF', pbc=False) [-0.26100004] [-341.97854242]
# alf3 Atoms(symbols='AlF3', pbc=False) [-0.68678963] [-541.67300648]
# alh Atoms(symbols='AlH', pbc=False) [-0.11724126] [-242.69949789]
# alh3 Atoms(symbols='AlH3', pbc=False) [-0.33970642] [-243.91895368]
# allene Atoms(symbols='C3H4', pbc=False) [-1.12205477] [-116.503411]
# b Atoms(symbols='B', pbc=False) [] []
# b2 Atoms(symbols='B2', pbc=False) [-0.10750276] [-49.30775175]
# b2h6 Atoms(symbols='B2H6', pbc=False) [-0.96735273] [-53.18736169]
# be Atoms(symbols='Be', pbc=False) [] []
# be2 Atoms(symbols='Be2', pbc=False) [-0.00425332] [-29.2706554]
# becl2 Atoms(symbols='BeCl2', pbc=False) [-0.35899697] [-934.49893692]
# bef2 Atoms(symbols='BeF2', pbc=False) [-0.49258061] [-214.40046975]
# bf Atoms(symbols='FB', pbc=False) [-0.29085935] [-124.54348213]
# bf3 Atoms(symbols='BF3', pbc=False) [-0.75054325] [-324.28081807]
# bh Atoms(symbols='BH', pbc=False) [-0.13544815] [-25.24920631]
# bh3 Atoms(symbols='BH3', pbc=False) [-0.44825937] [-26.5586341]
# bhf2 Atoms(symbols='BHF2', pbc=False) [-0.65492716] [-225.04527725]
# bn Atoms(symbols='BN', pbc=False) [-0.16770902] [-79.31145475 -79.30740177]
# bn3pi Atoms(symbols='BN', pbc=False) [-0.16862694] [-79.31145475 -79.30740177]
# c Atoms(symbols='C', pbc=False) [] []
# c-hcoh Atoms(symbols='CHOH', pbc=False) [-0.50620272] [-114.29168335 -114.29945866]
# c-hono Atoms(symbols='ONOH', pbc=False) [-0.49755265] [-205.50593087 -205.50655713]
# c-hooo Atoms(symbols='O3H', pbc=False) [-0.37145097] [-225.83841649 -225.83876529]
# c-n2h2 Atoms(symbols='HN2H', pbc=False) [-0.46395315] [-110.51810376 -110.52689425]
# c2 Atoms(symbols='C2', pbc=False) [-0.23429606] [-75.82549445]
# c2h2 Atoms(symbols='HC2H', pbc=False) [-0.64624522] [-77.23377996]
# c2h3f Atoms(symbols='C2H3F', pbc=False) [-0.91455512] [-177.64160097]
# c2h4 Atoms(symbols='C2H4', pbc=False) [-0.8989426] [-78.48495984]
# c2h5f Atoms(symbols='FC2H5', pbc=False) [-1.14978662] [-178.8757255]
# c2h6 Atoms(symbols='C2H6', pbc=False) [-1.13636531] [-79.72090346]
# cch Atoms(symbols='C2H', pbc=False) [-0.42415774] [-76.48789328]
# ccl2 Atoms(symbols='CCl2', pbc=False) [-0.28263637] [-957.58194773]
# cf Atoms(symbols='CF', pbc=False) [-0.21150438] [-137.64827281]
# cf2 Atoms(symbols='CF2', pbc=False) [-0.41239537] [-237.48785712]
# cf4 Atoms(symbols='FCF3', pbc=False) [-0.76295262] [-437.11962027]
# ch Atoms(symbols='CH', pbc=False) [-0.13421471] [-38.43080325]
# ch2-sing Atoms(symbols='CH2', pbc=False) [-0.28916854] [-39.08326056 -39.06496612]
# ch2-trip Atoms(symbols='CH2', pbc=False) [-0.30397151] [-39.08326056 -39.06496612]
# ch2c Atoms(symbols='C2H2', pbc=False) [-0.57359134] [-77.16175787]
# ch2ch Atoms(symbols='CHCH2', pbc=False) [-0.71087532] [-77.79795014]
# ch2f2 Atoms(symbols='CH2F2', pbc=False) [-0.69746835] [-238.77130252]
# ch2nh Atoms(symbols='CNH3', pbc=False) [-0.70029381] [-94.52121455]
# ch2nh2 Atoms(symbols='CH2NH2', pbc=False) [-0.76855573] [-95.08860068]
# ch3 Atoms(symbols='CH3', pbc=False) [-0.49062207] [-39.78390708]
# ch3f Atoms(symbols='FCH3', pbc=False) [-0.67402807] [-139.60662194]
# ch3nh Atoms(symbols='CH3NH', pbc=False) [-0.75636946] [-95.07720713]
# ch3nh2 Atoms(symbols='CNH5', pbc=False) [-0.92795571] [-95.74684413]
# ch4 Atoms(symbols='HCH3', pbc=False) [-0.66998192] [-40.46148005]
# cl Atoms(symbols='Cl', pbc=False) [] []
# cl2 Atoms(symbols='Cl2', pbc=False) [-0.09521769] [-919.59597296]
# cl2o Atoms(symbols='OCl2', pbc=False) [-0.16168202] [-994.65443263]
# clcn Atoms(symbols='ClCN', pbc=False) [-0.45488875] [-552.53264695]
# clf Atoms(symbols='ClF', pbc=False) [-0.10007817] [-559.48939583]
# clo Atoms(symbols='ClO', pbc=False) [-0.10429643] [-534.84527878]
# cloo Atoms(symbols='ClO2', pbc=False) [-0.20140732] [-609.93148529 -609.92975692]
# cn Atoms(symbols='CN', pbc=False) [-0.28899962] [-92.61062925]
# co Atoms(symbols='CO', pbc=False) [-0.41390132] [-113.2017293]
# co2 Atoms(symbols='CO2', pbc=False) [-0.62172926] [-188.40176179]
# cs Atoms(symbols='CS', pbc=False) [-0.27444685] [-435.87414091]
# cs2 Atoms(symbols='CS2', pbc=False) [-0.44744822] [-833.85151926]
# dioxirane Atoms(symbols='CH2O2', pbc=False) [-0.6534228] [-189.4286791]
# ethanol Atoms(symbols='HOC2H5', pbc=False) [-1.29279482] [-154.86919887]
# f Atoms(symbols='F', pbc=False) [] []
# f2 Atoms(symbols='F2', pbc=False) [-0.06221739] [-199.33682715]
# f2co Atoms(symbols='OCF2', pbc=False) [-0.67032613] [-312.73755788]
# f2o Atoms(symbols='FOF', pbc=False) [-0.14944794] [-274.41416188]
# fccf Atoms(symbols='FC2F', pbc=False) [-0.6152688] [-275.48698928]
# fo2 Atoms(symbols='FO2', pbc=False) [-0.21469158] [-249.83029635]
# foof Atoms(symbols='FO2F', pbc=False) [-0.24281546] [-349.49731138]
# formic Atoms(symbols='CHO2H', pbc=False) [-0.79982697] [-189.57631944]
# glyoxal Atoms(symbols='C2H2O2', pbc=False) [-1.01209787] [-227.58449186]
# h Atoms(symbols='H', pbc=False) [] []
# h2 Atoms(symbols='H2', pbc=False) [-0.1744882] [-1.17234853]
# h2cn Atoms(symbols='CH2N', pbc=False) [-0.5477989] [-93.8697648]
# h2co Atoms(symbols='OCH2', pbc=False) [-0.59705553] [-114.38243937]
# h2o Atoms(symbols='OH2', pbc=False) [-0.3712677] [-76.36044536]
# h2s Atoms(symbols='SH2', pbc=False) [-0.29308402] [-399.09610715]
# hccf Atoms(symbols='C2HF', pbc=False) [-0.63500555] [-176.36467361]
# hcl Atoms(symbols='ClH', pbc=False) [-0.17131056] [-460.42351109]
# hcn Atoms(symbols='HCN', pbc=False) [-0.49946338] [-93.32181545]
# hcnh Atoms(symbols='CHNH', pbc=False) [-0.53584689] [-93.85746001]
# hcno Atoms(symbols='CHNO', pbc=False) [-0.58161831] [-168.3955611]
# hco Atoms(symbols='OCH', pbc=False) [-0.4452873] [-113.73194946]
# hcof Atoms(symbols='COHF', pbc=False) [-0.64340543] [-213.56943041]
# hf Atoms(symbols='FH', pbc=False) [-0.22571771] [-100.36474161]
# hnc Atoms(symbols='HNC', pbc=False) [-0.47521673] [-93.29844687]
# hnco Atoms(symbols='CONH', pbc=False) [-0.69279751] [-168.50751035]
# hnnn Atoms(symbols='HN3', pbc=False) [-0.52873305] [-164.61159247]
# hno Atoms(symbols='NHO', pbc=False) [-0.3281066] [-130.34659319]
# hocl Atoms(symbols='OHCl', pbc=False) [-0.26490277] [-535.50545194]
# hocn Atoms(symbols='CNOH', pbc=False) [-0.65348177] [-168.46807325]
# hof Atoms(symbols='HOF', pbc=False) [-0.25282965] [-175.37982732]
# honc Atoms(symbols='HONC', pbc=False) [-0.55799795] [-168.37280913]
# hoo Atoms(symbols='O2H', pbc=False) [-0.27972964] [-150.75926322]
# hooh Atoms(symbols='HO2H', pbc=False) [-0.42882062] [-151.40703157]
# hs Atoms(symbols='SH', pbc=False) [-0.13980825] [-398.44564322]
# ketene Atoms(symbols='CH2CO', pbc=False) [-0.85012581] [-152.43050473]
# methanol Atoms(symbols='CH3OH', pbc=False) [-0.81831593] [-115.60136654]
# n Atoms(symbols='N', pbc=False) [] []
# n2 Atoms(symbols='N2', pbc=False) [-0.36411402] [-109.41917957]
# n2h Atoms(symbols='HN2', pbc=False) [-0.35834359] [-109.9128793]
# n2h4 Atoms(symbols='N2H4', pbc=False) [-0.69844523] [-111.75026467]
# n2o Atoms(symbols='N2O', pbc=False) [-0.43162536] [-184.47902214]
# nccn Atoms(symbols='NC2N', pbc=False) [-0.80004689] [-185.44919898]
# nh Atoms(symbols='NH', pbc=False) [-0.13242191] [-55.09249157]
# nh2 Atoms(symbols='NH2', pbc=False) [-0.29097728] [-55.81849798]
# nh2cl Atoms(symbols='NH2Cl', pbc=False) [-0.39530718] [-515.67327644]
# nh3 Atoms(symbols='NH3', pbc=False) [-0.47492191] [-56.50004506]
# no Atoms(symbols='NO', pbc=False) [-0.24341465] [-129.76325523]
# no2 Atoms(symbols='NO2', pbc=False) [-0.36315308] [-204.8729742]
# o Atoms(symbols='O', pbc=False) [] []
# o2 Atoms(symbols='O2', pbc=False) [-0.1925453] [-150.12623343]
# o3 Atoms(symbols='O3', pbc=False) [-0.23494147] [-225.20224348]
# oclo Atoms(symbols='ClO2', pbc=False) [-0.20417222] [-609.93148529 -609.92975692]
# ocs Atoms(symbols='OCS', pbc=False) [-0.5350469] [-511.12719909]
# of Atoms(symbols='OF', pbc=False) [-0.0845804] [-174.7127559]
# oh Atoms(symbols='OH', pbc=False) [-0.17084682] [-75.66226307]
# oxirane Atoms(symbols='OC2H4', pbc=False) [-1.03827277] [-153.61658326]
# oxirene Atoms(symbols='C2H2O', pbc=False) [-0.726797] [-152.30556322]
# p Atoms(symbols='P', pbc=False) [] []
# p2 Atoms(symbols='P2', pbc=False) [-0.18739637] [-682.1310539]
# p4 Atoms(symbols='P4', pbc=False) [-0.46306552] [-1364.34251518]
# ph3 Atoms(symbols='PH3', pbc=False) [-0.38607704] [-342.85729084]
# propane Atoms(symbols='CH3CH2CH3', pbc=False) [-1.60620523] [-118.98417293]
# propene Atoms(symbols='C3H6', pbc=False) [-1.37301194] [-117.75235108]
# propyne Atoms(symbols='H4C3', pbc=False) [-1.12445314] [-116.50549196]
# s Atoms(symbols='S', pbc=False) [] []
# s2 Atoms(symbols='S2', pbc=False) [-0.16613454] [-795.74373535]
# s2o Atoms(symbols='S2O', pbc=False) [-0.3327137] [-870.92202177]
# s3 Atoms(symbols='S3', pbc=False) [-0.26830511] [-1193.67148951]
# s4-c2v Atoms(symbols='S4', pbc=False) [-0.37345731] [-1591.57488048]
# si Atoms(symbols='Si', pbc=False) [] []
# si2h6 Atoms(symbols='SiH3SiH3', pbc=False) [-0.85398711] [-582.0227557]
# sif Atoms(symbols='FSi', pbc=False) [-0.22742286] [-388.95147745]
# sif4 Atoms(symbols='FSiF3', pbc=False) [-0.92075104] [-688.54481735]
# sih Atoms(symbols='HSi', pbc=False) [-0.11780061] [-289.70776715]
# sih3f Atoms(symbols='FSiH3', pbc=False) [-0.60995573] [-390.82978605]
# sih4 Atoms(symbols='HSiH3', pbc=False) [-0.51783282] [-291.60213075]
# sio Atoms(symbols='SiO', pbc=False) [-0.30764794] [-364.38223804]
# so Atoms(symbols='SO', pbc=False) [-0.20153481] [-472.95744066]
# so2 Atoms(symbols='SO2', pbc=False) [-0.415326] [-548.19126332]
# so3 Atoms(symbols='SO3', pbc=False) [-0.55288886] [-623.31414261]
# ssh Atoms(symbols='SHS', pbc=False) [-0.26314822] [-796.36752357]
# t-hcoh Atoms(symbols='CHOH', pbc=False) [-0.51389981] [-114.29168335 -114.29945866]
# t-hono Atoms(symbols='ONOH', pbc=False) [-0.4982379] [-205.50593087 -205.50655713]
# t-hooo Atoms(symbols='O3H', pbc=False) [-0.37178243] [-225.83841649 -225.83876529]
# t-n2h2 Atoms(symbols='HN2H', pbc=False) [-0.47255701] [-110.51810376 -110.52689425]

# %% [markdown]
# The polarized case.

# %%
w4p = '/home/awills/Documents/Research/datasets/W4-11'
w4cp = '/home/awills/Documents/Research/swxcd/aegis/w411_p'
w4ref = pd.read_csv(os.path.join(w4p, 'ref.dat'), delimiter='\t', skiprows=1, index_col=False, header=None)[[1, 11]]
w4ref.columns = ['name', 'en'] #energy in kcal/mol
w4ref['en_H'] = -w4ref['en'].values/Hart_to_kcalmol
w4ref['name'] = w4ref['name'].str.strip()

w4cc = pd.read_csv(os.path.join(w4cp, 'progress'), delimiter='\t')
w4cc.columns = [i.strip() for i in w4cc.columns]
w4cc['atoms.symbols'] = w4cc['atoms.symbols'].str.strip()

sdirs = sorted([i for i in os.listdir(w4p) if os.path.isdir(os.path.join(w4p, i))])
atoms = []
for idir in sdirs:
    at = read(os.path.join(w4p,idir,'struc.xyz'), ':')[0]
    sym = str(at.symbols)
    cce = w4cc[w4cc['atoms.symbols'] == sym]['etot  (Har)'].values
    eref = w4ref[w4ref['name'] == idir]['en_H'].values
    print(idir, at, eref, cce)
    try:
        at.info['atomization'] = eref[0]
        at.info['energy'] = cce[0]
        atoms.append(at)
    except:
        #energy not in dataframe, so not one of the AEs. probably single atom
        continue
write(os.path.join(w4cp, 'calc_ref_results.traj'), atoms)
# Out:
# acetaldehyde Atoms(symbols='COHCH3', pbc=False) [-1.08024505] [-153.65854663]
# acetic Atoms(symbols='C2O2H4', pbc=False) [-1.28128265] [-228.85096313]
# al Atoms(symbols='Al', pbc=False) [] []
# alcl Atoms(symbols='AlCl', pbc=False) [-0.19540422] [-702.02772785]
# alcl3 Atoms(symbols='AlCl3', pbc=False) [-0.49824108] [-1621.83173863]
# alf Atoms(symbols='AlF', pbc=False) [-0.26100004] [-341.97854249]
# alf3 Atoms(symbols='AlF3', pbc=False) [-0.68678963] [-541.67300646]
# alh Atoms(symbols='AlH', pbc=False) [-0.11724126] [-242.6994979]
# alh3 Atoms(symbols='AlH3', pbc=False) [-0.33970642] [-243.91895368]
# allene Atoms(symbols='C3H4', pbc=False) [-1.12205477] [-116.50341088]
# b Atoms(symbols='B', pbc=False) [] []
# b2 Atoms(symbols='B2', pbc=False) [-0.10750276] [-49.32538976]
# b2h6 Atoms(symbols='B2H6', pbc=False) [-0.96735273] [-53.18736149]
# be Atoms(symbols='Be', pbc=False) [] []
# be2 Atoms(symbols='Be2', pbc=False) [-0.00425332] [-29.2706554]
# becl2 Atoms(symbols='BeCl2', pbc=False) [-0.35899697] [-934.49893688]
# bef2 Atoms(symbols='BeF2', pbc=False) [-0.49258061] [-214.40046975]
# bf Atoms(symbols='FB', pbc=False) [-0.29085935] [-124.54348213]
# bf3 Atoms(symbols='BF3', pbc=False) [-0.75054325] [-324.28081806]
# bh Atoms(symbols='BH', pbc=False) [-0.13544815] [-25.24920632]
# bh3 Atoms(symbols='BH3', pbc=False) [-0.44825937] [-26.55863409]
# bhf2 Atoms(symbols='BHF2', pbc=False) [-0.65492716] [-225.04527721]
# bn Atoms(symbols='BN', pbc=False) [-0.16770902] [-79.31145438 -79.30740091]
# bn3pi Atoms(symbols='BN', pbc=False) [-0.16862694] [-79.31145438 -79.30740091]
# c Atoms(symbols='C', pbc=False) [] []
# c-hcoh Atoms(symbols='CHOH', pbc=False) [-0.50620272] [-114.29168332 -114.29945867]
# c-hono Atoms(symbols='ONOH', pbc=False) [-0.49755265] [-205.50593089 -205.5065572 ]
# c-hooo Atoms(symbols='O3H', pbc=False) [-0.37145097] [-225.83841649 -225.83876529]
# c-n2h2 Atoms(symbols='HN2H', pbc=False) [-0.46395315] [-110.51810375 -110.52689423]
# c2 Atoms(symbols='C2', pbc=False) [-0.23429606] [-75.8254945]
# c2h2 Atoms(symbols='HC2H', pbc=False) [-0.64624522] [-77.23377998]
# c2h3f Atoms(symbols='C2H3F', pbc=False) [-0.91455512] [-177.64160097]
# c2h4 Atoms(symbols='C2H4', pbc=False) [-0.8989426] [-78.48495984]
# c2h5f Atoms(symbols='FC2H5', pbc=False) [-1.14978662] [-178.87572553]
# c2h6 Atoms(symbols='C2H6', pbc=False) [-1.13636531] [-79.72090345]
# cch Atoms(symbols='C2H', pbc=False) [-0.42415774] [-76.48789328]
# ccl2 Atoms(symbols='CCl2', pbc=False) [-0.28263637] [-957.58194759]
# cf Atoms(symbols='CF', pbc=False) [-0.21150438] [-137.64827281]
# cf2 Atoms(symbols='CF2', pbc=False) [-0.41239537] [-237.48785711]
# cf4 Atoms(symbols='FCF3', pbc=False) [-0.76295262] [-437.11962026]
# ch Atoms(symbols='CH', pbc=False) [-0.13421471] [-38.43080325]
# ch2-sing Atoms(symbols='CH2', pbc=False) [-0.28916854] [-39.08326059 -39.0649661 ]
# ch2-trip Atoms(symbols='CH2', pbc=False) [-0.30397151] [-39.08326059 -39.0649661 ]
# ch2c Atoms(symbols='C2H2', pbc=False) [-0.57359134] [-77.16175784]
# ch2ch Atoms(symbols='CHCH2', pbc=False) [-0.71087532] [-77.79795014]
# ch2f2 Atoms(symbols='CH2F2', pbc=False) [-0.69746835] [-238.77130248]
# ch2nh Atoms(symbols='CNH3', pbc=False) [-0.70029381] [-94.52119085]
# ch2nh2 Atoms(symbols='CH2NH2', pbc=False) [-0.76855573] [-95.08860068]
# ch3 Atoms(symbols='CH3', pbc=False) [-0.49062207] [-39.78390708]
# ch3f Atoms(symbols='FCH3', pbc=False) [-0.67402807] [-139.60662194]
# ch3nh Atoms(symbols='CH3NH', pbc=False) [-0.75636946] [-95.07720713]
# ch3nh2 Atoms(symbols='CNH5', pbc=False) [-0.92795571] [-95.7468441]
# ch4 Atoms(symbols='HCH3', pbc=False) [-0.66998192] [-40.46148001]
# cl Atoms(symbols='Cl', pbc=False) [] []
# cl2 Atoms(symbols='Cl2', pbc=False) [-0.09521769] [-919.59597293]
# cl2o Atoms(symbols='OCl2', pbc=False) [-0.16168202] [-994.65443262]
# clcn Atoms(symbols='ClCN', pbc=False) [-0.45488875] [-552.532647]
# clf Atoms(symbols='ClF', pbc=False) [-0.10007817] [-559.4893958]
# clo Atoms(symbols='ClO', pbc=False) [-0.10429643] [-534.84527878]
# cloo Atoms(symbols='ClO2', pbc=False) [-0.20140732] [-609.93148529 -609.92975692]
# cn Atoms(symbols='CN', pbc=False) [-0.28899962] [-92.61062925]
# co Atoms(symbols='CO', pbc=False) [-0.41390132] [-113.2017293]
# co2 Atoms(symbols='CO2', pbc=False) [-0.62172926] [-188.40176179]
# cs Atoms(symbols='CS', pbc=False) [-0.27444685] [-435.8741408]
# cs2 Atoms(symbols='CS2', pbc=False) [-0.44744822] [-833.85151916]
# dioxirane Atoms(symbols='CH2O2', pbc=False) [-0.6534228] [-189.42867911]
# ethanol Atoms(symbols='HOC2H5', pbc=False) [-1.29279482] [-154.86919897]
# f Atoms(symbols='F', pbc=False) [] []
# f2 Atoms(symbols='F2', pbc=False) [-0.06221739] [-199.33682717]
# f2co Atoms(symbols='OCF2', pbc=False) [-0.67032613] [-312.73755787]
# f2o Atoms(symbols='FOF', pbc=False) [-0.14944794] [-274.41416176]
# fccf Atoms(symbols='FC2F', pbc=False) [-0.6152688] [-275.48698927]
# fo2 Atoms(symbols='FO2', pbc=False) [-0.21469158] [-249.83029635]
# foof Atoms(symbols='FO2F', pbc=False) [-0.24281546] [-349.49731141]
# formic Atoms(symbols='CHO2H', pbc=False) [-0.79982697] [-189.57631933]
# glyoxal Atoms(symbols='C2H2O2', pbc=False) [-1.01209787] [-227.58449191]
# h Atoms(symbols='H', pbc=False) [] []
# h2 Atoms(symbols='H2', pbc=False) [-0.1744882] [-1.17234855]
# h2cn Atoms(symbols='CH2N', pbc=False) [-0.5477989] [-93.8697648]
# h2co Atoms(symbols='OCH2', pbc=False) [-0.59705553] [-114.38243934]
# h2o Atoms(symbols='OH2', pbc=False) [-0.3712677] [-76.36044535]
# h2s Atoms(symbols='SH2', pbc=False) [-0.29308402] [-399.09610715]
# hccf Atoms(symbols='C2HF', pbc=False) [-0.63500555] [-176.36467365]
# hcl Atoms(symbols='ClH', pbc=False) [-0.17131056] [-460.42351101]
# hcn Atoms(symbols='HCN', pbc=False) [-0.49946338] [-93.32181546]
# hcnh Atoms(symbols='CHNH', pbc=False) [-0.53584689] [-93.85746001]
# hcno Atoms(symbols='CHNO', pbc=False) [-0.58161831] [-168.39556112]
# hco Atoms(symbols='OCH', pbc=False) [-0.4452873] [-113.73194946]
# hcof Atoms(symbols='COHF', pbc=False) [-0.64340543] [-213.56943042]
# hf Atoms(symbols='FH', pbc=False) [-0.22571771] [-100.36474159]
# hnc Atoms(symbols='HNC', pbc=False) [-0.47521673] [-93.29844688]
# hnco Atoms(symbols='CONH', pbc=False) [-0.69279751] [-168.50751035]
# hnnn Atoms(symbols='HN3', pbc=False) [-0.52873305] [-164.61159244]
# hno Atoms(symbols='NHO', pbc=False) [-0.3281066] [-130.34659319]
# hocl Atoms(symbols='OHCl', pbc=False) [-0.26490277] [-535.50545192]
# hocn Atoms(symbols='CNOH', pbc=False) [-0.65348177] [-168.46807326]
# hof Atoms(symbols='HOF', pbc=False) [-0.25282965] [-175.37982682]
# honc Atoms(symbols='HONC', pbc=False) [-0.55799795] [-168.37280914]
# hoo Atoms(symbols='O2H', pbc=False) [-0.27972964] [-150.75926322]
# hooh Atoms(symbols='HO2H', pbc=False) [-0.42882062] [-151.40703153]
# hs Atoms(symbols='SH', pbc=False) [-0.13980825] [-398.44564322]
# ketene Atoms(symbols='CH2CO', pbc=False) [-0.85012581] [-152.43050473]
# methanol Atoms(symbols='CH3OH', pbc=False) [-0.81831593] [-115.60136656]
# n Atoms(symbols='N', pbc=False) [] []
# n2 Atoms(symbols='N2', pbc=False) [-0.36411402] [-109.41917942]
# n2h Atoms(symbols='HN2', pbc=False) [-0.35834359] [-109.9128793]
# n2h4 Atoms(symbols='N2H4', pbc=False) [-0.69844523] [-111.75026458]
# n2o Atoms(symbols='N2O', pbc=False) [-0.43162536] [-184.47902214]
# nccn Atoms(symbols='NC2N', pbc=False) [-0.80004689] [-185.449199]
# nh Atoms(symbols='NH', pbc=False) [-0.13242191] [-55.0924915]
# nh2 Atoms(symbols='NH2', pbc=False) [-0.29097728] [-55.81849798]
# nh2cl Atoms(symbols='NH2Cl', pbc=False) [-0.39530718] [-515.67327643]
# nh3 Atoms(symbols='NH3', pbc=False) [-0.47492191] [-56.50004505]
# no Atoms(symbols='NO', pbc=False) [-0.24341465] [-129.76325523]
# no2 Atoms(symbols='NO2', pbc=False) [-0.36315308] [-204.8729742]
# o Atoms(symbols='O', pbc=False) [] []
# o2 Atoms(symbols='O2', pbc=False) [-0.1925453] [-150.1585762]
# o3 Atoms(symbols='O3', pbc=False) [-0.23494147] [-225.20224346]
# oclo Atoms(symbols='ClO2', pbc=False) [-0.20417222] [-609.93148529 -609.92975692]
# ocs Atoms(symbols='OCS', pbc=False) [-0.5350469] [-511.12719909]
# of Atoms(symbols='OF', pbc=False) [-0.0845804] [-174.7127559]
# oh Atoms(symbols='OH', pbc=False) [-0.17084682] [-75.66226307]
# oxirane Atoms(symbols='OC2H4', pbc=False) [-1.03827277] [-153.61658329]
# oxirene Atoms(symbols='C2H2O', pbc=False) [-0.726797] [-152.30556323]
# p Atoms(symbols='P', pbc=False) [] []
# p2 Atoms(symbols='P2', pbc=False) [-0.18739637] [-682.13105388]
# p4 Atoms(symbols='P4', pbc=False) [-0.46306552] [-1364.34251521]
# ph3 Atoms(symbols='PH3', pbc=False) [-0.38607704] [-342.85729079]
# propane Atoms(symbols='CH3CH2CH3', pbc=False) [-1.60620523] [-118.98417291]
# propene Atoms(symbols='C3H6', pbc=False) [-1.37301194] [-117.75235104]
# propyne Atoms(symbols='H4C3', pbc=False) [-1.12445314] [-116.50549193]
# s Atoms(symbols='S', pbc=False) [] []
# s2 Atoms(symbols='S2', pbc=False) [-0.16613454] [-795.76249152]
# s2o Atoms(symbols='S2O', pbc=False) [-0.3327137] [-870.92202183]
# s3 Atoms(symbols='S3', pbc=False) [-0.26830511] [-1193.67148946]
# s4-c2v Atoms(symbols='S4', pbc=False) [-0.37345731] [-1591.57488048]
# si Atoms(symbols='Si', pbc=False) [] []
# si2h6 Atoms(symbols='SiH3SiH3', pbc=False) [-0.85398711] [-582.02275569]
# sif Atoms(symbols='FSi', pbc=False) [-0.22742286] [-388.95147745]
# sif4 Atoms(symbols='FSiF3', pbc=False) [-0.92075104] [-688.54481735]
# sih Atoms(symbols='HSi', pbc=False) [-0.11780061] [-289.70776715]
# sih3f Atoms(symbols='FSiH3', pbc=False) [-0.60995573] [-390.82978605]
# sih4 Atoms(symbols='HSiH3', pbc=False) [-0.51783282] [-291.60213076]
# sio Atoms(symbols='SiO', pbc=False) [-0.30764794] [-364.38223803]
# so Atoms(symbols='SO', pbc=False) [-0.20153481] [-472.95744048]
# so2 Atoms(symbols='SO2', pbc=False) [-0.415326] [-548.19126332]
# so3 Atoms(symbols='SO3', pbc=False) [-0.55288886] [-623.31414262]
# ssh Atoms(symbols='SHS', pbc=False) [-0.26314822] [-796.36752357]
# t-hcoh Atoms(symbols='CHOH', pbc=False) [-0.51389981] [-114.29168332 -114.29945867]
# t-hono Atoms(symbols='ONOH', pbc=False) [-0.4982379] [-205.50593089 -205.5065572 ]
# t-hooo Atoms(symbols='O3H', pbc=False) [-0.37178243] [-225.83841649 -225.83876529]
# t-n2h2 Atoms(symbols='HN2H', pbc=False) [-0.47255701] [-110.51810375 -110.52689423]

# %%
for idx, at in enumerate(atoms):
    print(idx, at, at.info)
# Out:
# 0 Atoms(symbols='COHCH3', pbc=False) {'': True, 'atomization': -1.0802450452229493, 'energy': -153.65854662583965}
# 1 Atoms(symbols='C2O2H4', pbc=False) {'': True, 'atomization': -1.2812826474411092, 'energy': -228.8509631250595}
# 2 Atoms(symbols='AlCl', pbc=False) {'': True, 'atomization': -0.19540422113454556, 'energy': -702.0277278479019}
# 3 Atoms(symbols='AlCl3', pbc=False) {'': True, 'atomization': -0.498241083217283, 'energy': -1621.8317386292113}
# 4 Atoms(symbols='AlF', pbc=False) {'': True, 'atomization': -0.261000043528812, 'energy': -341.9785424909245}
# 5 Atoms(symbols='AlF3', pbc=False) {'': True, 'atomization': -0.6867896309652065, 'energy': -541.6730064592647}
# 6 Atoms(symbols='AlH', pbc=False) {'': True, 'atomization': -0.11724125779957686, 'energy': -242.699497896186}
# 7 Atoms(symbols='AlH3', pbc=False) {'': True, 'atomization': -0.33970642495416614, 'energy': -243.91895367998052}
# 8 Atoms(symbols='C3H4', pbc=False) {'': True, 'atomization': -1.1220547725524272, 'energy': -116.50341088049744}
# 9 Atoms(symbols='B2', pbc=False) {'': True, 'atomization': -0.1075027594114674, 'energy': -49.325389759422976}
# 10 Atoms(symbols='B2H6', pbc=False) {'': True, 'atomization': -0.9673527257478939, 'energy': -53.18736149209348}
# 11 Atoms(symbols='Be2', pbc=False) {'': True, 'atomization': -0.004253322238236655, 'energy': -29.270655397156123}
# 12 Atoms(symbols='BeCl2', pbc=False) {'': True, 'atomization': -0.3589969703621297, 'energy': -934.4989368806706}
# 13 Atoms(symbols='BeF2', pbc=False) {'': True, 'atomization': -0.4925806109092213, 'energy': -214.4004697485967}
# 14 Atoms(symbols='FB', pbc=False) {'': True, 'atomization': -0.29085935367412497, 'energy': -124.54348213001298}
# 15 Atoms(symbols='BF3', pbc=False) {'': True, 'atomization': -0.750543250097052, 'energy': -324.28081805977257}
# 16 Atoms(symbols='BH', pbc=False) {'': True, 'atomization': -0.13544815422964573, 'energy': -25.249206315325}
# 17 Atoms(symbols='BH3', pbc=False) {'': True, 'atomization': -0.4482593677133285, 'energy': -26.558634090186107}
# 18 Atoms(symbols='BHF2', pbc=False) {'': True, 'atomization': -0.6549271638122266, 'energy': -225.04527720734723}
# 19 Atoms(symbols='BN', pbc=False) {'': True, 'atomization': -0.16770902174214586, 'energy': -79.31145437792942}
# 20 Atoms(symbols='BN', pbc=False) {'': True, 'atomization': -0.1686269361704802, 'energy': -79.31145437792942}
# 21 Atoms(symbols='CHOH', pbc=False) {'': True, 'atomization': -0.5062027160019328, 'energy': -114.29168332399624}
# 22 Atoms(symbols='ONOH', pbc=False) {'': True, 'atomization': -0.4975526473960322, 'energy': -205.5059308914179}
# 23 Atoms(symbols='O3H', pbc=False) {'': True, 'atomization': -0.3714509656007282, 'energy': -225.8384164923021}
# 24 Atoms(symbols='HN2H', pbc=False) {'': True, 'atomization': -0.46395315467554454, 'energy': -110.51810374977268}
# 25 Atoms(symbols='C2', pbc=False) {'': True, 'atomization': -0.23429606423089833, 'energy': -75.82549449644941}
# 26 Atoms(symbols='HC2H', pbc=False) {'': True, 'atomization': -0.6462452231775644, 'energy': -77.23377998216539}
# 27 Atoms(symbols='C2H3F', pbc=False) {'': True, 'atomization': -0.9145551165028514, 'energy': -177.64160097116496}
# 28 Atoms(symbols='C2H4', pbc=False) {'': True, 'atomization': -0.8989426032139775, 'energy': -78.48495984282073}
# 29 Atoms(symbols='FC2H5', pbc=False) {'': True, 'atomization': -1.1497866247779027, 'energy': -178.8757255254844}
# 30 Atoms(symbols='C2H6', pbc=False) {'': True, 'atomization': -1.1363653134663896, 'energy': -79.7209034518602}
# 31 Atoms(symbols='C2H', pbc=False) {'': True, 'atomization': -0.4241577395638002, 'energy': -76.48789328091758}
# 32 Atoms(symbols='CCl2', pbc=False) {'': True, 'atomization': -0.28263637025363, 'energy': -957.581947593248}
# 33 Atoms(symbols='CF', pbc=False) {'': True, 'atomization': -0.21150437646347212, 'energy': -137.64827280512907}
# 34 Atoms(symbols='CF2', pbc=False) {'': True, 'atomization': -0.4123953673493285, 'energy': -237.48785711257335}
# 35 Atoms(symbols='FCF3', pbc=False) {'': True, 'atomization': -0.7629526244953843, 'energy': -437.1196202645618}
# 36 Atoms(symbols='CH', pbc=False) {'': True, 'atomization': -0.13421470671657149, 'energy': -38.4308032460303}
# 37 Atoms(symbols='CH2', pbc=False) {'': True, 'atomization': -0.2891685425483216, 'energy': -39.08326058756125}
# 38 Atoms(symbols='CH2', pbc=False) {'': True, 'atomization': -0.3039715063066507, 'energy': -39.08326058756125}
# 39 Atoms(symbols='C2H2', pbc=False) {'': True, 'atomization': -0.5735913400140398, 'energy': -77.16175784498859}
# 40 Atoms(symbols='CHCH2', pbc=False) {'': True, 'atomization': -0.7108753231003542, 'energy': -77.79795014426458}
# 41 Atoms(symbols='CH2F2', pbc=False) {'': True, 'atomization': -0.6974683542017835, 'energy': -238.771302483932}
# 42 Atoms(symbols='CNH3', pbc=False) {'': True, 'atomization': -0.7002938095515, 'energy': -94.52119084656424}
# 43 Atoms(symbols='CH2NH2', pbc=False) {'': True, 'atomization': -0.7685557271516751, 'energy': -95.08860068306932}
# 44 Atoms(symbols='CH3', pbc=False) {'': True, 'atomization': -0.49062207474182046, 'energy': -39.78390708068967}
# 45 Atoms(symbols='FCH3', pbc=False) {'': True, 'atomization': -0.6740280706490586, 'energy': -139.6066219422689}
# 46 Atoms(symbols='CH3NH', pbc=False) {'': True, 'atomization': -0.7563694569546742, 'energy': -95.07720713283486}
# 47 Atoms(symbols='CNH5', pbc=False) {'': True, 'atomization': -0.9279557109956696, 'energy': -95.74684410371458}
# 48 Atoms(symbols='HCH3', pbc=False) {'': True, 'atomization': -0.6699819165977724, 'energy': -40.46148001354251}
# 49 Atoms(symbols='Cl2', pbc=False) {'': True, 'atomization': -0.0952176859253054, 'energy': -919.5959729252116}
# 50 Atoms(symbols='OCl2', pbc=False) {'': True, 'atomization': -0.1616820211033257, 'energy': -994.6544326232028}
# 51 Atoms(symbols='ClCN', pbc=False) {'': True, 'atomization': -0.4548887496957431, 'energy': -552.5326469981496}
# 52 Atoms(symbols='ClF', pbc=False) {'': True, 'atomization': -0.10007817031145069, 'energy': -559.4893958001454}
# 53 Atoms(symbols='ClO', pbc=False) {'': True, 'atomization': -0.10429643331804958, 'energy': -534.8452787780333}
# 54 Atoms(symbols='ClO2', pbc=False) {'': True, 'atomization': -0.20140731775179455, 'energy': -609.9314852891674}
# 55 Atoms(symbols='CN', pbc=False) {'': True, 'atomization': -0.2889996207958851, 'energy': -92.61062924652708}
# 56 Atoms(symbols='CO', pbc=False) {'': True, 'atomization': -0.41390132070831454, 'energy': -113.20172930064096}
# 57 Atoms(symbols='CO2', pbc=False) {'': True, 'atomization': -0.6217292586541352, 'energy': -188.40176178572835}
# 58 Atoms(symbols='CS', pbc=False) {'': True, 'atomization': -0.2744468524633346, 'energy': -435.8741407990888}
# 59 Atoms(symbols='CS2', pbc=False) {'': True, 'atomization': -0.44744822458134564, 'energy': -833.8515191551058}
# 60 Atoms(symbols='CH2O2', pbc=False) {'': True, 'atomization': -0.6534228040546787, 'energy': -189.42867911089965}
# 61 Atoms(symbols='HOC2H5', pbc=False) {'': True, 'atomization': -1.2927948242298022, 'energy': -154.8691989708035}
# 62 Atoms(symbols='F2', pbc=False) {'': True, 'atomization': -0.06221738734553596, 'energy': -199.3368271746121}
# 63 Atoms(symbols='OCF2', pbc=False) {'': True, 'atomization': -0.6703261345083977, 'energy': -312.7375578662194}
# 64 Atoms(symbols='FOF', pbc=False) {'': True, 'atomization': -0.14944794286318228, 'energy': -274.41416175511824}
# 65 Atoms(symbols='FC2F', pbc=False) {'': True, 'atomization': -0.615268798424157, 'energy': -275.4869892703793}
# 66 Atoms(symbols='FO2', pbc=False) {'': True, 'atomization': -0.21469157933963295, 'energy': -249.8302963472776}
# 67 Atoms(symbols='FO2F', pbc=False) {'': True, 'atomization': -0.2428154575188763, 'energy': -349.4973114095449}
# 68 Atoms(symbols='CHO2H', pbc=False) {'': True, 'atomization': -0.7998269681711273, 'energy': -189.5763193282561}
# 69 Atoms(symbols='C2H2O2', pbc=False) {'': True, 'atomization': -1.012097866926316, 'energy': -227.58449190924844}
# 70 Atoms(symbols='H2', pbc=False) {'': True, 'atomization': -0.17448820225974, 'energy': -1.1723485500967412}
# 71 Atoms(symbols='CH2N', pbc=False) {'': True, 'atomization': -0.5477989007387081, 'energy': -93.86976479567863}
# 72 Atoms(symbols='OCH2', pbc=False) {'': True, 'atomization': -0.5970555275883359, 'energy': -114.38243934281743}
# 73 Atoms(symbols='OH2', pbc=False) {'': True, 'atomization': -0.37126770143534893, 'energy': -76.36044535420797}
# 74 Atoms(symbols='SH2', pbc=False) {'': True, 'atomization': -0.29308402128168526, 'energy': -399.0961071535568}
# 75 Atoms(symbols='C2HF', pbc=False) {'': True, 'atomization': -0.6350055522347832, 'energy': -176.36467364641933}
# 76 Atoms(symbols='ClH', pbc=False) {'': True, 'atomization': -0.17131056099220762, 'energy': -460.4235110092302}
# 77 Atoms(symbols='HCN', pbc=False) {'': True, 'atomization': -0.4994633755202907, 'energy': -93.32181545564136}
# 78 Atoms(symbols='CHNH', pbc=False) {'': True, 'atomization': -0.5358468899531049, 'energy': -93.85746001352231}
# 79 Atoms(symbols='CHNO', pbc=False) {'': True, 'atomization': -0.5816183104576509, 'energy': -168.39556111984584}
# 80 Atoms(symbols='OCH', pbc=False) {'': True, 'atomization': -0.4452873010313086, 'energy': -113.73194945710956}
# 81 Atoms(symbols='COHF', pbc=False) {'': True, 'atomization': -0.6434054254149051, 'energy': -213.56943041560405}
# 82 Atoms(symbols='FH', pbc=False) {'': True, 'atomization': -0.2257177076897114, 'energy': -100.36474159157996}
# 83 Atoms(symbols='HNC', pbc=False) {'': True, 'atomization': -0.475216729639897, 'energy': -93.298446878627}
# 84 Atoms(symbols='CONH', pbc=False) {'': True, 'atomization': -0.6927975083867698, 'energy': -168.50751035227822}
# 85 Atoms(symbols='HN3', pbc=False) {'': True, 'atomization': -0.5287330531335139, 'energy': -164.6115924351716}
# 86 Atoms(symbols='NHO', pbc=False) {'': True, 'atomization': -0.3281066000863787, 'energy': -130.34659319014187}
# 87 Atoms(symbols='OHCl', pbc=False) {'': True, 'atomization': -0.264902773450671, 'energy': -535.5054519207407}
# 88 Atoms(symbols='CNOH', pbc=False) {'': True, 'atomization': -0.6534817673078875, 'energy': -168.46807326091638}
# 89 Atoms(symbols='HOF', pbc=False) {'': True, 'atomization': -0.25282964895577364, 'energy': -175.37982682300284}
# 90 Atoms(symbols='HONC', pbc=False) {'': True, 'atomization': -0.5579979499424228, 'energy': -168.3728091351132}
# 91 Atoms(symbols='O2H', pbc=False) {'': True, 'atomization': -0.27972964123057126, 'energy': -150.7592632239829}
# 92 Atoms(symbols='HO2H', pbc=False) {'': True, 'atomization': -0.4288206173716235, 'energy': -151.407031526602}
# 93 Atoms(symbols='SH', pbc=False) {'': True, 'atomization': -0.13980824776423376, 'energy': -398.445643218191}
# 94 Atoms(symbols='CH2CO', pbc=False) {'': True, 'atomization': -0.8501258103612597, 'energy': -152.43050473313556}
# 95 Atoms(symbols='CH3OH', pbc=False) {'': True, 'atomization': -0.8183159320557364, 'energy': -115.60136656144792}
# 96 Atoms(symbols='N2', pbc=False) {'': True, 'atomization': -0.36411402457980596, 'energy': -109.41917942044968}
# 97 Atoms(symbols='HN2', pbc=False) {'': True, 'atomization': -0.35834359377251673, 'energy': -109.91287930456274}
# 98 Atoms(symbols='N2H4', pbc=False) {'': True, 'atomization': -0.6984452318833269, 'energy': -111.75026458025812}
# 99 Atoms(symbols='N2O', pbc=False) {'': True, 'atomization': -0.43162535590264506, 'energy': -184.47902214126967}
# 100 Atoms(symbols='NC2N', pbc=False) {'': True, 'atomization': -0.8000468851695823, 'energy': -185.44919899598287}
# 101 Atoms(symbols='NH', pbc=False) {'': True, 'atomization': -0.132421905098731, 'energy': -55.09249149891524}
# 102 Atoms(symbols='NH2', pbc=False) {'': True, 'atomization': -0.2909772801805429, 'energy': -55.81849797949497}
# 103 Atoms(symbols='NH2Cl', pbc=False) {'': True, 'atomization': -0.39530717912879215, 'energy': -515.6732764347254}
# 104 Atoms(symbols='NH3', pbc=False) {'': True, 'atomization': -0.4749219133738521, 'energy': -56.50004505149356}
# 105 Atoms(symbols='NO', pbc=False) {'': True, 'atomization': -0.24341465165959453, 'energy': -129.7632552340172}
# 106 Atoms(symbols='NO2', pbc=False) {'': True, 'atomization': -0.3631530829126434, 'energy': -204.8729741960793}
# 107 Atoms(symbols='O2', pbc=False) {'': True, 'atomization': -0.19254530015462928, 'energy': -150.15857619635142}
# 108 Atoms(symbols='O3', pbc=False) {'': True, 'atomization': -0.2349414728133209, 'energy': -225.2022434562362}
# 109 Atoms(symbols='ClO2', pbc=False) {'': True, 'atomization': -0.20417221624686407, 'energy': -609.9314852891674}
# 110 Atoms(symbols='OCS', pbc=False) {'': True, 'atomization': -0.5350469020311885, 'energy': -511.1271990870698}
# 111 Atoms(symbols='OF', pbc=False) {'': True, 'atomization': -0.08458039632611856, 'energy': -174.71275589748058}
# 112 Atoms(symbols='OH', pbc=False) {'': True, 'atomization': -0.17084682297372622, 'energy': -75.66226307277074}
# 113 Atoms(symbols='OC2H4', pbc=False) {'': True, 'atomization': -1.038272770546787, 'energy': -153.61658329469088}
# 114 Atoms(symbols='C2H2O', pbc=False) {'': True, 'atomization': -0.7267969950682156, 'energy': -152.30556323322585}
# 115 Atoms(symbols='P2', pbc=False) {'': True, 'atomization': -0.18739637390819144, 'energy': -682.1310538802788}
# 116 Atoms(symbols='P4', pbc=False) {'': True, 'atomization': -0.4630655186745337, 'energy': -1364.342515209025}
# 117 Atoms(symbols='PH3', pbc=False) {'': True, 'atomization': -0.38607703959943035, 'energy': -342.8572907901499}
# 118 Atoms(symbols='CH3CH2CH3', pbc=False) {'': True, 'atomization': -1.6062052318542033, 'energy': -118.98417290971628}
# 119 Atoms(symbols='C3H6', pbc=False) {'': True, 'atomization': -1.3730119398184564, 'energy': -117.75235104274029}
# 120 Atoms(symbols='H4C3', pbc=False) {'': True, 'atomization': -1.1244531427167384, 'energy': -116.50549193159736}
# 121 Atoms(symbols='S2', pbc=False) {'': True, 'atomization': -0.1661345435213224, 'energy': -795.7624915218778}
# 122 Atoms(symbols='S2O', pbc=False) {'': True, 'atomization': -0.3327137018438692, 'energy': -870.9220218282921}
# 123 Atoms(symbols='S3', pbc=False) {'': True, 'atomization': -0.2683051125209727, 'energy': -1193.671489457011}
# 124 Atoms(symbols='S4', pbc=False) {'': True, 'atomization': -0.3734573098112715, 'energy': -1591.574880477532}
# 125 Atoms(symbols='SiH3SiH3', pbc=False) {'': True, 'atomization': -0.8539871066457286, 'energy': -582.0227556876048}
# 126 Atoms(symbols='FSi', pbc=False) {'': True, 'atomization': -0.22742286122845748, 'energy': -388.9514774529532}
# 127 Atoms(symbols='FSiF3', pbc=False) {'': True, 'atomization': -0.9207510388941079, 'energy': -688.5448173468966}
# 128 Atoms(symbols='HSi', pbc=False) {'': True, 'atomization': -0.11780061190434311, 'energy': -289.7077671532965}
# 129 Atoms(symbols='FSiH3', pbc=False) {'': True, 'atomization': -0.6099557312295969, 'energy': -390.8297860469731}
# 130 Atoms(symbols='HSiH3', pbc=False) {'': True, 'atomization': -0.5178328192970437, 'energy': -291.602130756528}
# 131 Atoms(symbols='SiO', pbc=False) {'': True, 'atomization': -0.3076479448243022, 'energy': -364.3822380312486}
# 132 Atoms(symbols='SO', pbc=False) {'': True, 'atomization': -0.20153480586684097, 'energy': -472.95744047600186}
# 133 Atoms(symbols='SO2', pbc=False) {'': True, 'atomization': -0.41532600039395845, 'energy': -548.1912633234695}
# 134 Atoms(symbols='SO3', pbc=False) {'': True, 'atomization': -0.5528888637319369, 'energy': -623.3141426172411}
# 135 Atoms(symbols='SHS', pbc=False) {'': True, 'atomization': -0.2631482182673444, 'energy': -796.367523569335}
# 136 Atoms(symbols='CHOH', pbc=False) {'': True, 'atomization': -0.5138998109478612, 'energy': -114.29168332399624}
# 137 Atoms(symbols='ONOH', pbc=False) {'': True, 'atomization': -0.4982378960144068, 'energy': -205.5059308914179}
# 138 Atoms(symbols='O3H', pbc=False) {'': True, 'atomization': -0.37178243469984895, 'energy': -225.8384164923021}
# 139 Atoms(symbols='HN2H', pbc=False) {'': True, 'atomization': -0.4725570088397408, 'energy': -110.51810374977268}
