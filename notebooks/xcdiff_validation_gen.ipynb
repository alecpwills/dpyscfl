# %%
from torch.utils.data import DataLoader 
import torch
import matplotlib.pyplot as plt
from pyscf import gto, dft, scf 
from pyscf.lib import chkfile
# from kspies import wy, zmp
from dpyscfl.scf import *
from dpyscfl.net import *
from dpyscfl.utils import *
from dpyscfl.losses import *
import os, shutil, copy
from ase import Atoms, Atom
from ase.units import Bohr, Hartree, kcal, mol
import pickle
import pandas as pd
from ase.io import read, write
# from torchviz import make_dot
import pylibnxc
kcal_mol = kcal/mol
kcal_mol
Hart_to_kcalmol = Hartree/kcal_mol


#spins for single atoms, since pyscf doesn't guess this correctly.
spins_dict = {
    'Al': 1,
    'B' : 1,
    'Li': 1,
    'Na': 1,
    'Si': 2 ,
    'Be':0,
    'C': 2,
    'Cl': 1,
    'F': 1,
    'H': 1,
    'N': 3,
    'O': 2,
    'P': 3,
    'S': 2
}

def get_spin(at):
    #if single atom and spin is not specified in at.info dictionary, use spins_dict
    if ( (len(at.positions) == 1) and not ('spin' in at.info) ):
        spin = spins_dict[str(at.symbols)]
    else:
        if at.info.get('spin', None):
            print('Spin specified in atom info.')
            spin = at.info['spin']
        elif 'radical' in at.info.get('name', ''):
            print('Radical specified in atom.info["name"], assuming spin 1.')
            spin = 1
        elif at.info.get('openshell', None):
            print("Openshell specified in atom info, attempting spin 2.")
            spin = 2
        else:
            print("No specifications in atom info to help, assuming no spin.")
            spin = 0
    return spin

# %% [markdown]
# The referenced G2/97 dataset is located [here](https://pubs.aip.org/aip/jcp/article/136/16/164102/190335/New-accurate-reference-energies-for-the-G2-97-test).
#
# The referenced BH76 dataset may be found [here](http://www.thch.uni-bonn.de/tc.old/downloads/GMTKN/GMTKN55/BH76.html).

# %% [markdown]
# # Small Subset for Validation
#
# - BF3 = 1972.30 kJ/mol
# - C2H2 = 1695.79 kJ/mol
# - LiH = 242.27 kJ/mol
# - NO = 639.28 kJ/mol
#
# And the constituent atoms, with energies from the [reference](https://journals.aps.org/pra/pdf/10.1103/PhysRevA.47.3649) (table XI, neutral column -- energies are already given in Hartrees):
# - B = -24.65391
# - F = -99.7339
# - C = -37.8450
# - H = -0.5
# - Li = -7.47808
# - N = -54.5892
# - O = -75.0673
#
# For BF3, 1972.30 kJ/mol = 20.4414 eV. So energies in the below trajectory are stored in eV.

# %%
for at in g2:
    print(at, at.info)
# Out:
# Atoms(symbols='OC', pbc=False, calculator=SinglePointCalculator(...)) {'CO': True, 'name': 'Carbon monoxide', 'openshell': False}
# Atoms(symbols='CS', pbc=False, calculator=SinglePointCalculator(...)) {'CS': True, 'name': 'Carbon monosulfide', 'openshell': False}
# Atoms(symbols='H2', pbc=False, calculator=SinglePointCalculator(...)) {'H2': True, 'name': 'Dihydrogen', 'openshell': False}
# Atoms(symbols='FH', pbc=False, calculator=SinglePointCalculator(...)) {'HF': True, 'name': 'Hydrogen fluoride', 'openshell': False}
# Atoms(symbols='P2', pbc=False, calculator=SinglePointCalculator(...)) {'P2': True, 'name': 'Diphosphorus', 'openshell': False}
# Atoms(symbols='S2', pbc=False, calculator=SinglePointCalculator(...)) {'S2': True, 'name': 'Disulfur', 'openshell': True}
# Atoms(symbols='SH', pbc=False, calculator=SinglePointCalculator(...)) {'HS': True, 'name': 'Mercapto radical', 'openshell': True}
# Atoms(symbols='OS', pbc=False, calculator=SinglePointCalculator(...)) {'OS': True, 'name': 'Sulfur monoxide', 'openshell': True}
# Atoms(symbols='C2H', pbc=False, calculator=SinglePointCalculator(...)) {'C2H': True, 'name': 'Ethynyl radical', 'openshell': True}
# Atoms(symbols='CF4', pbc=False, calculator=SinglePointCalculator(...)) {'CF4': True, 'name': 'Tetrafluoromethane', 'openshell': False}
# Atoms(symbols='CH4', pbc=False, calculator=SinglePointCalculator(...)) {'CH4': True, 'name': 'Methane', 'openshell': False}
# Atoms(symbols='CO2', pbc=False, calculator=SinglePointCalculator(...)) {'CO2': True, 'name': 'Carbon dioxide', 'openshell': False}
# Atoms(symbols='SCS', pbc=False, calculator=SinglePointCalculator(...)) {'CS2': True, 'name': 'Carbon disulfide', 'openshell': False}
# Atoms(symbols='FOF', pbc=False, calculator=SinglePointCalculator(...)) {'OF2': True, 'name': 'Difluorine monoxide', 'openshell': False}
# Atoms(symbols='BeH', pbc=False, calculator=SinglePointCalculator(...)) {'BeH': True, 'name': 'Beryllium monohydride', 'openshell': True}
# Atoms(symbols='OH2', pbc=False, calculator=SinglePointCalculator(...)) {'H2O': True, 'name': 'Water', 'openshell': False}
# Atoms(symbols='SH2', pbc=False, calculator=SinglePointCalculator(...)) {'H2S': True, 'name': 'Hydrogen sulfide', 'openshell': False}
# Atoms(symbols='Cl2', pbc=False, calculator=SinglePointCalculator(...)) {'Cl2': True, 'name': 'Dichlorine', 'openshell': False}
# Atoms(symbols='CNH', pbc=False, calculator=SinglePointCalculator(...)) {'CNH': True, 'name': 'Hydrogen cyanide', 'openshell': False}
# Atoms(symbols='COH', pbc=False, calculator=SinglePointCalculator(...)) {'CHO': True, 'name': 'Formyl radical', 'openshell': True}
# Atoms(symbols='ClH', pbc=False, calculator=SinglePointCalculator(...)) {'HCl': True, 'name': 'Hydrogen chloride', 'openshell': False}
# Atoms(symbols='N2O', pbc=False, calculator=SinglePointCalculator(...)) {'N2O': True, 'name': 'Nitrous oxide', 'openshell': False}
# Atoms(symbols='NF3', pbc=False, calculator=SinglePointCalculator(...)) {'NF3': True, 'name': 'Trifluoroamine', 'openshell': False}
# Atoms(symbols='NO2', pbc=False, calculator=SinglePointCalculator(...)) {'NO2': True, 'name': 'Nitrogen dioxide', 'openshell': True}
# Atoms(symbols='Li2', pbc=False, calculator=SinglePointCalculator(...)) {'Li2': True, 'name': 'Dilithium', 'openshell': False}
# Atoms(symbols='LiF', pbc=False, calculator=SinglePointCalculator(...)) {'LiF': True, 'name': 'Lithium fluoride', 'openshell': False}
# Atoms(symbols='LiH', pbc=False, calculator=SinglePointCalculator(...)) {'LiH': True, 'name': 'Lithium hydride', 'openshell': False, 'e_H': 0.09227576969496765, 'e_ev': 2.510951589865373, 'atomization': -0.09227576969496765}
# Atoms(symbols='PF3', pbc=False, calculator=SinglePointCalculator(...)) {'PF3': True, 'name': 'Phosphorus trifluoride', 'openshell': False}
# Atoms(symbols='PH3', pbc=False, calculator=SinglePointCalculator(...)) {'PH3': True, 'name': 'Phosphane', 'openshell': False}
# Atoms(symbols='Na2', pbc=False, calculator=SinglePointCalculator(...)) {'Na2': True, 'name': 'Disodium', 'openshell': False}
# Atoms(symbols='SO2', pbc=False, calculator=SinglePointCalculator(...)) {'SO2': True, 'name': 'Sulfur dioxide', 'openshell': False}
# Atoms(symbols='SiO', pbc=False, calculator=SinglePointCalculator(...)) {'SiO': True, 'name': 'Silicon monoxide', 'openshell': False}
# Atoms(symbols='C5H8', pbc=False, calculator=SinglePointCalculator(...)) {'C5H8': True, 'name': 'Spiropentane', 'openshell': False}
# Atoms(symbols='C3H4', pbc=False, calculator=SinglePointCalculator(...)) {'C3H4': True, 'name': 'Allene', 'openshell': False}
# Atoms(symbols='C2H3', pbc=False, calculator=SinglePointCalculator(...)) {'C2H3': True, 'name': 'Vinyl radical', 'openshell': True}
# Atoms(symbols='C2H5', pbc=False, calculator=SinglePointCalculator(...)) {'C2H5': True, 'name': 'Ethyl radical', 'openshell': True}
# Atoms(symbols='CCl4', pbc=False, calculator=SinglePointCalculator(...)) {'CCl4': True, 'name': 'Tetrachloromethane', 'openshell': False}
# Atoms(symbols='COH3', pbc=False, calculator=SinglePointCalculator(...)) {'CH3O': True, 'name': 'Methoxy radical', 'openshell': True}
# Atoms(symbols='CSH3', pbc=False, calculator=SinglePointCalculator(...)) {'CH3S': True, 'name': 'Methylthio radical', 'openshell': True}
# Atoms(symbols='CHF3', pbc=False, calculator=SinglePointCalculator(...)) {'CHF3': True, 'name': 'Trifluoromethane', 'openshell': False}
# Atoms(symbols='OCF2', pbc=False, calculator=SinglePointCalculator(...)) {'COF2': True, 'name': 'Carbonyl fluoride', 'openshell': False}
# Atoms(symbols='AlF3', pbc=False, calculator=SinglePointCalculator(...)) {'AlF3': True, 'name': 'Aluminum trifluoride', 'openshell': False}
# Atoms(symbols='OCH2', pbc=False, calculator=SinglePointCalculator(...)) {'CH2O': True, 'name': 'Formaldehyde', 'openshell': False}
# Atoms(symbols='O2H2', pbc=False, calculator=SinglePointCalculator(...)) {'H2O2': True, 'name': 'Hydrogen peroxide', 'openshell': False}
# Atoms(symbols='ClF3', pbc=False, calculator=SinglePointCalculator(...)) {'F3Cl': True, 'name': 'Chlorine trifluoride', 'openshell': False}
# Atoms(symbols='ClNO', pbc=False, calculator=SinglePointCalculator(...)) {'NOCl': True, 'name': 'Nitrosyl chloride', 'openshell': False}
# Atoms(symbols='OHCl', pbc=False, calculator=SinglePointCalculator(...)) {'HOCl': True, 'name': 'Hypochlorous acid', 'openshell': False}
# Atoms(symbols='NaCl', pbc=False, calculator=SinglePointCalculator(...)) {'NaCl': True, 'name': 'Sodium chloride', 'openshell': False}
# Atoms(symbols='SiF4', pbc=False, calculator=SinglePointCalculator(...)) {'SiF4': True, 'name': 'Silicon tetrafluoride', 'openshell': False}
# Atoms(symbols='SiH3', pbc=False, calculator=SinglePointCalculator(...)) {'SiH3': True, 'name': 'Silyl radical', 'openshell': True}
# Atoms(symbols='SiH4', pbc=False, calculator=SinglePointCalculator(...)) {'SiH4': True, 'name': 'Silane', 'openshell': False}
# Atoms(symbols='C3H3ClH4', pbc=False, calculator=SinglePointCalculator(...)) {'C3H7Cl': True, 'name': '1-Chloropropane', 'openshell': False}
# Atoms(symbols='N2H4', pbc=False, calculator=SinglePointCalculator(...)) {'N2H4': True, 'name': 'Hydrazine', 'openshell': False}
# Atoms(symbols='OCOH2', pbc=False, calculator=SinglePointCalculator(...)) {'CH2O2': True, 'name': 'Formic acid', 'openshell': False}
# Atoms(symbols='C2H4', pbc=False, calculator=SinglePointCalculator(...)) {'C2H4': True, 'name': 'Ethylene', 'openshell': False}
# Atoms(symbols='C4H8', pbc=False, calculator=SinglePointCalculator(...)) {'C4H8': True, 'name': 'Cyclobutane', 'openshell': False}
# Atoms(symbols='C4H6', pbc=False, calculator=SinglePointCalculator(...)) {'C4H6': True, 'name': 'Cyclobutene', 'openshell': False}
# Atoms(symbols='SOC2H6', pbc=False, calculator=SinglePointCalculator(...)) {'C2H6OS': True, 'name': 'Dimethyl sulfoxide', 'openshell': False}
# Atoms(symbols='NH3', pbc=False, calculator=SinglePointCalculator(...)) {'NH3': True, 'name': 'Ammonia', 'openshell': False}
# Atoms(symbols='C2H6', pbc=False, calculator=SinglePointCalculator(...)) {'C2H6': True, 'name': 'Ethane', 'openshell': False}
# Atoms(symbols='C2F3N', pbc=False, calculator=SinglePointCalculator(...)) {'C2NF3': True, 'name': 'Trifluoroacetonitril', 'openshell': False}
# Atoms(symbols='BCl3', pbc=False, calculator=SinglePointCalculator(...)) {'BCl3': True, 'name': 'Boron trichloride', 'openshell': False}
# Atoms(symbols='CF2H2', pbc=False, calculator=SinglePointCalculator(...)) {'CH2F2': True, 'name': 'Difluoromethane', 'openshell': False}
# Atoms(symbols='C2H3O', pbc=False, calculator=SinglePointCalculator(...)) {'C2H3O': True, 'name': 'Carbonyl methane', 'openshell': True}
# Atoms(symbols='CClH3', pbc=False, calculator=SinglePointCalculator(...)) {'CH3Cl': True, 'name': 'Chloromethane', 'openshell': False}
# Atoms(symbols='CSH4', pbc=False, calculator=SinglePointCalculator(...)) {'CH4S': True, 'name': 'Thiomethanol', 'openshell': False}
# Atoms(symbols='CHCl3', pbc=False, calculator=SinglePointCalculator(...)) {'CHCl3': True, 'name': 'Trichloromethane', 'openshell': False}
# Atoms(symbols='AlCl3', pbc=False, calculator=SinglePointCalculator(...)) {'AlCl3': True, 'name': 'Aluminum trichloride', 'openshell': False}
# Atoms(symbols='COH3', pbc=False, calculator=SinglePointCalculator(...)) {'CH3O': True, 'name': 'Hydroxymethyl radical', 'openshell': True}
# Atoms(symbols='OC4H4', pbc=False, calculator=SinglePointCalculator(...)) {'C4H4O': True, 'name': 'Furan', 'openshell': False}
# Atoms(symbols='OC3H8', pbc=False, calculator=SinglePointCalculator(...)) {'C3H8O': True, 'name': 'Methoxyethane', 'openshell': False}
# Atoms(symbols='C6H6', pbc=False, calculator=SinglePointCalculator(...)) {'C6H6': True, 'name': 'Benzene', 'openshell': False}
# Atoms(symbols='OCS', pbc=False, calculator=SinglePointCalculator(...)) {'COS': True, 'name': 'Carbonyl sulfide', 'openshell': False}
# Atoms(symbols='C2SH6', pbc=False, calculator=SinglePointCalculator(...)) {'C2H6S': True, 'name': 'Thioethanol', 'openshell': False}
# Atoms(symbols='Si2H6', pbc=False, calculator=SinglePointCalculator(...)) {'Si2H6': True, 'name': 'Disilane', 'openshell': False}
# Atoms(symbols='SiCl4', pbc=False, calculator=SinglePointCalculator(...)) {'SiCl4': True, 'name': 'Silicon tetrachloride', 'openshell': False}
# Atoms(symbols='C4H9', pbc=False, calculator=SinglePointCalculator(...)) {'C4H9': True, 'name': 'tert-Butyl radical', 'openshell': True}
# Atoms(symbols='C2H2O', pbc=False, calculator=SinglePointCalculator(...)) {'C2H2O': True, 'name': 'Ketene', 'openshell': False}
# Atoms(symbols='C4H10', pbc=False, calculator=SinglePointCalculator(...)) {'C4H10': True, 'name': 'n-Butane', 'openshell': False}
# Atoms(symbols='CO2HCH3', pbc=False, calculator=SinglePointCalculator(...)) {'C2H4O2': True, 'name': 'Acetic acid', 'openshell': False}
# Atoms(symbols='FCl', pbc=False, calculator=SinglePointCalculator(...)) {'FCl': True, 'name': 'Chlorine monofluoride', 'openshell': False}
# Atoms(symbols='OCHCH3', pbc=False, calculator=SinglePointCalculator(...)) {'C2H4O': True, 'name': 'Acetaldehyde', 'openshell': False}
# Atoms(symbols='COCH4', pbc=False, calculator=SinglePointCalculator(...)) {'C2H4O': True, 'name': 'Oxirane', 'openshell': False}
# Atoms(symbols='NO', pbc=False, calculator=SinglePointCalculator(...)) {'NO': True, 'name': 'Nitric oxide', 'openshell': True, 'e_H': 0.24348889276674332, 'e_ev': 6.625670253721614, 'atomization': -0.24348889276674332}
# Atoms(symbols='NH', pbc=False, calculator=SinglePointCalculator(...)) {'NH': True, 'name': 'Imidogen', 'openshell': True}
# Atoms(symbols='CO2HCH3', pbc=False, calculator=SinglePointCalculator(...)) {'C2H4O2': True, 'name': 'Methyl formate', 'openshell': False}
# Atoms(symbols='C4H6', pbc=False, calculator=SinglePointCalculator(...)) {'C4H6': True, 'name': '2-Butyne', 'openshell': False}
# Atoms(symbols='CNH5', pbc=False, calculator=SinglePointCalculator(...)) {'CNH5': True, 'name': 'Methylamine', 'openshell': False}
# Atoms(symbols='ClO', pbc=False, calculator=SinglePointCalculator(...)) {'OCl': True, 'name': 'Monochlorine monoxide', 'openshell': True}
# Atoms(symbols='C3H8', pbc=False, calculator=SinglePointCalculator(...)) {'C3H8': True, 'name': 'Propane', 'openshell': False}
# Atoms(symbols='C2H3CH3', pbc=False, calculator=SinglePointCalculator(...)) {'C3H6': True, 'name': 'Propene', 'openshell': False}
# Atoms(symbols='C3H4', pbc=False, calculator=SinglePointCalculator(...)) {'C3H4': True, 'name': 'Propyne', 'openshell': False}
# Atoms(symbols='C4H6', pbc=False, calculator=SinglePointCalculator(...)) {'C4H6': True, 'name': 'Methylenecyclopropane', 'openshell': False}
# Atoms(symbols='SiH2', pbc=False, calculator=SinglePointCalculator(...)) {'SiH2': True, 'name': 'Singlet silylene', 'openshell': False}
# Atoms(symbols='SiH2', pbc=False, calculator=SinglePointCalculator(...)) {'SiH2': True, 'name': 'Triplet silylene', 'openshell': True}
# Atoms(symbols='CSCH4', pbc=False, calculator=SinglePointCalculator(...)) {'C2H4S': True, 'name': 'Thiirane', 'openshell': False}
# Atoms(symbols='CNO2H3', pbc=False, calculator=SinglePointCalculator(...)) {'CNH3O2': True, 'name': 'Nitromethane', 'openshell': False}
# Atoms(symbols='C3H7', pbc=False, calculator=SinglePointCalculator(...)) {'C3H7': True, 'name': 'Isopropyl radical', 'openshell': True}
# Atoms(symbols='C2ONH5', pbc=False, calculator=SinglePointCalculator(...)) {'C2NH5O': True, 'name': 'Acetamide', 'openshell': False}
# Atoms(symbols='HNC4H4', pbc=False, calculator=SinglePointCalculator(...)) {'C4NH5': True, 'name': 'Pyrrole', 'openshell': False}
# Atoms(symbols='COFCH3', pbc=False, calculator=SinglePointCalculator(...)) {'C2H3OF': True, 'name': 'Acetyl fluoride', 'openshell': False}
# Atoms(symbols='C2H2', pbc=False, calculator=SinglePointCalculator(...)) {'C2H2': True, 'name': 'Acetylene', 'openshell': False, 'e_H': 0.6458922998762915, 'e_ev': 17.575624702100136, 'atomization': -0.6458922998762915}
# Atoms(symbols='C2FH3', pbc=False, calculator=SinglePointCalculator(...)) {'C2H3F': True, 'name': 'Vinyl fluoride', 'openshell': False}
# Atoms(symbols='NC2N', pbc=False, calculator=SinglePointCalculator(...)) {'C2N2': True, 'name': 'Cyanogen', 'openshell': False}
# Atoms(symbols='C2ClH5', pbc=False, calculator=SinglePointCalculator(...)) {'C2H5Cl': True, 'name': 'Ethyl chloride', 'openshell': False}
# Atoms(symbols='CH2', pbc=False, calculator=SinglePointCalculator(...)) {'CH2': True, 'name': 'Singlet carbene', 'openshell': True}
# Atoms(symbols='CH2', pbc=False, calculator=SinglePointCalculator(...)) {'CH2': True, 'name': 'Triplet carbene', 'openshell': True}
# Atoms(symbols='OH', pbc=False, calculator=SinglePointCalculator(...)) {'HO': True, 'name': 'Hydroxyl radical', 'openshell': True}
# Atoms(symbols='CH', pbc=False, calculator=SinglePointCalculator(...)) {'CH': True, 'name': 'Methylidyne radical', 'openshell': True}
# Atoms(symbols='NC5H5', pbc=False, calculator=SinglePointCalculator(...)) {'C5NH5': True, 'name': 'Pyridine', 'openshell': False}
# Atoms(symbols='Si2', pbc=False, calculator=SinglePointCalculator(...)) {'Si2': True, 'name': 'Disilicon', 'openshell': True}
# Atoms(symbols='C3H6', pbc=False, calculator=SinglePointCalculator(...)) {'C3H6': True, 'name': 'Cyclopropane', 'openshell': False}
# Atoms(symbols='C3H4', pbc=False, calculator=SinglePointCalculator(...)) {'C3H4': True, 'name': 'Cyclopropene', 'openshell': False}
# Atoms(symbols='N2', pbc=False, calculator=SinglePointCalculator(...)) {'N2': True, 'name': 'Dinitrogen', 'openshell': False}
# Atoms(symbols='F2', pbc=False, calculator=SinglePointCalculator(...)) {'F2': True, 'name': 'Difluorine', 'openshell': False}
# Atoms(symbols='CSiH6', pbc=False, calculator=SinglePointCalculator(...)) {'SiCH6': True, 'name': 'Methylsilane', 'openshell': False}
# Atoms(symbols='CH3', pbc=False, calculator=SinglePointCalculator(...)) {'CH3': True, 'name': 'Methyl radical', 'openshell': True}
# Atoms(symbols='PH2', pbc=False, calculator=SinglePointCalculator(...)) {'PH2': True, 'name': 'Phosphino radical', 'openshell': True}
# Atoms(symbols='NC3H9', pbc=False, calculator=SinglePointCalculator(...)) {'C3NH9': True, 'name': 'Trimethylamine', 'openshell': False}
# Atoms(symbols='C2OH6', pbc=False, calculator=SinglePointCalculator(...)) {'C2H6O': True, 'name': 'Ethanol', 'openshell': False}
# Atoms(symbols='CNCH7', pbc=False, calculator=SinglePointCalculator(...)) {'C2NH7': True, 'name': 'Dimethylamine', 'openshell': False}
# Atoms(symbols='O2', pbc=False, calculator=SinglePointCalculator(...)) {'O2': True, 'name': 'Dioxygen', 'openshell': True}
# Atoms(symbols='NH2', pbc=False, calculator=SinglePointCalculator(...)) {'NH2': True, 'name': 'Amino radical', 'openshell': True}
# Atoms(symbols='C2F4', pbc=False, calculator=SinglePointCalculator(...)) {'C2F4': True, 'name': 'Tetrafluoroethylene', 'openshell': False}
# Atoms(symbols='COH4', pbc=False, calculator=SinglePointCalculator(...)) {'CH4O': True, 'name': 'Methanol', 'openshell': False}
# Atoms(symbols='C4H6', pbc=False, calculator=SinglePointCalculator(...)) {'C4H6': True, 'name': '1,3-Butadiene', 'openshell': False}
# Atoms(symbols='C2OH5', pbc=False, calculator=SinglePointCalculator(...)) {'C2H5O': True, 'name': 'Ethoxy radical', 'openshell': True}
# Atoms(symbols='CSCH6', pbc=False, calculator=SinglePointCalculator(...)) {'C2H6S': True, 'name': 'Dimethyl sulfide', 'openshell': False}
# Atoms(symbols='CNCH5', pbc=False, calculator=SinglePointCalculator(...)) {'C2NH5': True, 'name': 'Aziridine', 'openshell': False}
# Atoms(symbols='C4H6', pbc=False, calculator=SinglePointCalculator(...)) {'C4H6': True, 'name': 'Bicyclo[1.1.0]butane', 'openshell': False}
# Atoms(symbols='C3H3N', pbc=False, calculator=SinglePointCalculator(...)) {'C3NH3': True, 'name': 'Acrylonitrile', 'openshell': False}
# Atoms(symbols='OCH2C2H6', pbc=False, calculator=SinglePointCalculator(...)) {'C3H8O': True, 'name': 'Isopropyl alcohol', 'openshell': False}
# Atoms(symbols='SC4H4', pbc=False, calculator=SinglePointCalculator(...)) {'C4H4S': True, 'name': 'Thiophene', 'openshell': False}
# Atoms(symbols='BF3', pbc=False, calculator=SinglePointCalculator(...)) {'BF3': True, 'name': 'Boron trifluoride', 'openshell': False, 'e_H': 0.7512093968274431, 'e_ev': 20.441448882203634, 'atomization': -0.7512093968274431}
# Atoms(symbols='C2Cl4', pbc=False, calculator=SinglePointCalculator(...)) {'C2Cl4': True, 'name': 'Tetrachloroethylene', 'openshell': False}
# Atoms(symbols='CHCH3CH3CH3', pbc=False, calculator=SinglePointCalculator(...)) {'C4H10': True, 'name': 'Isobutane', 'openshell': False}
# Atoms(symbols='C2H2CH3CH3', pbc=False, calculator=SinglePointCalculator(...)) {'C4H8': True, 'name': 'Isobutene', 'openshell': False}
# Atoms(symbols='COH3NO', pbc=False, calculator=SinglePointCalculator(...)) {'CNH3O2': True, 'name': 'Methyl nitrite', 'openshell': False}
# Atoms(symbols='OC3H6', pbc=False, calculator=SinglePointCalculator(...)) {'C3H6O': True, 'name': 'Acetone', 'openshell': False}
# Atoms(symbols='C2OHOH', pbc=False, calculator=SinglePointCalculator(...)) {'C2H2O2': True, 'name': 'Glyoxal', 'openshell': False}
# Atoms(symbols='C2ClOH3', pbc=False, calculator=SinglePointCalculator(...)) {'C2H3OCl': True, 'name': 'Acetyl chloride', 'openshell': False}
# Atoms(symbols='CN', pbc=False, calculator=SinglePointCalculator(...)) {'CN': True, 'name': 'Cyano radical', 'openshell': True}
# Atoms(symbols='C2NH7', pbc=False, calculator=SinglePointCalculator(...)) {'C2NH7': True, 'name': 'Ethylamine', 'openshell': False}
# Atoms(symbols='C2ClH3', pbc=False, calculator=SinglePointCalculator(...)) {'C2H3Cl': True, 'name': 'Vinyl chloride', 'openshell': False}
# Atoms(symbols='O3', pbc=False, calculator=SinglePointCalculator(...)) {'O3': True, 'name': 'Ozone', 'openshell': False}
# Atoms(symbols='C2NH3', pbc=False, calculator=SinglePointCalculator(...)) {'C2NH3': True, 'name': 'Acetonitrile', 'openshell': False}
# Atoms(symbols='CCl2H2', pbc=False, calculator=SinglePointCalculator(...)) {'CH2Cl2': True, 'name': 'Dichloromethane', 'openshell': False}
# Atoms(symbols='COCH6', pbc=False, calculator=SinglePointCalculator(...)) {'C2H6O': True, 'name': 'Dimethyl ether', 'openshell': False}

# %%
g2 = read('/home/awills/Documents/Research/xcdiff/data/haunschild_g2/g2_97.traj', ':')
# print(g2)
vals = ['BF3', 'LiH', 'NO', 'C2H2']
atvals = ['B','F','C','H','Li','N','O']
atens = [-24.65391, -99.7339, -37.8450, -0.5, -7.47806, -54.5892, -75.0673]
g2_sub = []
for idx, at in enumerate(g2):
    if str(at.symbols) in vals:
        at.info['e_H'] = at.calc.results['energy']/Hartree
        at.info['e_ev'] = at.calc.results['energy']
        at.info['atomization'] = -at.info['e_H']
        at.info['target_energy'] = -at.info['e_H']
        g2_sub.append(at)
        print(at.symbols)
        print(at.calc.results['energy'])
        print(at.info)
for idx, at in enumerate(atvals):
    single = Atoms(symbols=at)
    single.info['atomization'] = atens[idx]
    single.info['target_energy'] = atens[idx]
    single.info['e_H'] = atens[idx]
    single.info['spin'] = get_spin(single)
    g2_sub.append(single)
    
    print(single.symbols, single.info)
write('/home/awills/Documents/Research/swxcd/scont/valset/val.traj', g2_sub)
# Out:
# LiH
# 2.510951589865373
# {'LiH': True, 'name': 'Lithium hydride', 'openshell': False, 'e_H': 0.09227576969496765, 'e_ev': 2.510951589865373, 'atomization': -0.09227576969496765, 'target_energy': -0.09227576969496765}
# NO
# 6.625670253721614
# {'NO': True, 'name': 'Nitric oxide', 'openshell': True, 'e_H': 0.24348889276674332, 'e_ev': 6.625670253721614, 'atomization': -0.24348889276674332, 'target_energy': -0.24348889276674332}
# C2H2
# 17.575624702100136
# {'C2H2': True, 'name': 'Acetylene', 'openshell': False, 'e_H': 0.6458922998762915, 'e_ev': 17.575624702100136, 'atomization': -0.6458922998762915, 'target_energy': -0.6458922998762915}
# BF3
# 20.441448882203634
# {'BF3': True, 'name': 'Boron trifluoride', 'openshell': False, 'e_H': 0.7512093968274431, 'e_ev': 20.441448882203634, 'atomization': -0.7512093968274431, 'target_energy': -0.7512093968274431}
# B {'atomization': -24.65391, 'target_energy': -24.65391, 'e_H': -24.65391, 'spin': 1}
# F {'atomization': -99.7339, 'target_energy': -99.7339, 'e_H': -99.7339, 'spin': 1}
# C {'atomization': -37.845, 'target_energy': -37.845, 'e_H': -37.845, 'spin': 2}
# H {'atomization': -0.5, 'target_energy': -0.5, 'e_H': -0.5, 'spin': 1}
# Li {'atomization': -7.47808, 'target_energy': -7.47808, 'e_H': -7.47808, 'spin': 1}
# N {'atomization': -54.5892, 'target_energy': -54.5892, 'e_H': -54.5892, 'spin': 3}
# O {'atomization': -75.0673, 'target_energy': -75.0673, 'e_H': -75.0673, 'spin': 2}

# %% [markdown]
# ### The CCSD(T) calculations of this subset

# %%
cc_sub = read('/home/awills/Documents/Research/swxcd/scont/valset/ccsdt/results.traj', ':')
for idx, at in enumerate(cc_sub):
    print(idx, at, at.calc.results, at.info)
# Out:
# 0 Atoms(symbols='LiH', pbc=False, calculator=SinglePointCalculator(...)) {'energy': -8.038079906478368} {'LiH': True, 'name': 'Lithium hydride', 'openshell': False, 'e_H': 0.09227576969496765, 'e_ev': 2.510951589865373}
# 1 Atoms(symbols='NO', pbc=False, calculator=SinglePointCalculator(...)) {'energy': -129.7632739631654} {'NO': True, 'name': 'Nitric oxide', 'openshell': True, 'e_H': 0.24348889276674332, 'e_ev': 6.625670253721614}
# 2 Atoms(symbols='C2H2', pbc=False, calculator=SinglePointCalculator(...)) {'energy': -77.2336470993193} {'C2H2': True, 'name': 'Acetylene', 'openshell': False, 'e_H': 0.6458922998762915, 'e_ev': 17.575624702100136}
# 3 Atoms(symbols='BF3', pbc=False, calculator=SinglePointCalculator(...)) {'energy': -324.2808406836368} {'BF3': True, 'name': 'Boron trifluoride', 'openshell': False, 'e_H': 0.7512093968274431, 'e_ev': 20.441448882203634}

# %% [markdown]
# # Published Validation

# %%
#OH+N2 -> H+N2O ref energy is 0.132 Hart
ohn2 = 0.132*Hart_to_kcalmol
ohch3 = 0.0129*Hart_to_kcalmol
hff = 0.169*Hart_to_kcalmol
ohn2, ohch3, hff
# Out:
# (82.83125055346386, 8.094872213179421, 106.04910108738933)

# %%
n2oh = 17.7/Hart_to_kcalmol
ohcl = 9.9/Hart_to_kcalmol
n2oh, ohcl
# Out:
# (0.028206745454023522, 0.01577665423699621)

# %% [markdown]
# Validation is C2H2, BeH, NO2, S2, CH4, PF3, CH2, C2H4O2 atomization energies from G2/97 and N2O+H -> OH + N2, OH + CL -> O + HCl from BH76.

# %%
bh76 = read('/home/awills/Documents/Research/datasets/BH76/strucs_cm.traj',':')
g297 = read('/home/awills/Documents/Research/swxcd/aegis/g297_ps/caresults_os.traj',':')
# Out:
# /home/awills/anaconda3/envs/rsrch/lib/python3.7/site-packages/ase/io/jsonio.py:58: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   a = np.array(obj)

# %%
for idx, at in enumerate(g297):
    print(idx, at.get_chemical_formula(), at.info)
    print()
# Out:
# 0 CO {'CO': True, 'energy': -113.20173021777055, 'atomization': 0.4142335363320095, 'atomization_ev': 11.271868661369064, 'atomization_H': 0.4142335363320095, 'openshell': False, 'name': 'Carbon monoxide'}
#
# 1 CS {'CS': True, 'energy': -435.87414183611736, 'atomization': 0.2740316507303354, 'atomization_ev': 7.456781030917735, 'atomization_H': 0.2740316507303354, 'openshell': False, 'name': 'Carbon monosulfide'}
#
# 2 H2 {'H2': True, 'energy': -1.1723488681184566, 'atomization': 0.17434014967795244, 'atomization_ev': 4.7440371124327285, 'atomization_H': 0.17434014967795244, 'openshell': False, 'name': 'Dihydrogen'}
#
# 3 HF {'HF': True, 'energy': -100.36472229755955, 'atomization': 0.2258693892950415, 'atomization_ev': 6.146219143195457, 'atomization_H': 0.2258693892950415, 'openshell': False, 'name': 'Hydrogen fluoride'}
#
# 4 P2 {'P2': True, 'energy': -682.1310084499595, 'atomization': 0.18636071884282296, 'atomization_ev': 5.071133460210626, 'atomization_H': 0.18636071884282296, 'openshell': False, 'name': 'Diphosphorus'}
#
# 5 S2 {'S2': True, 'energy': -795.7439189734063, 'atomization': 0.1652790172181213, 'atomization_ev': 4.497471139250339, 'atomization_H': 0.1652790172181213, 'openshell': True, 'name': 'Disulfur'}
#
# 6 HS {'HS': True, 'energy': -398.44560089894645, 'atomization': 0.1396115217802055, 'atomization_ev': 3.799023012610527, 'atomization_H': 0.1396115217802055, 'openshell': True, 'name': 'Mercapto radical'}
#
# 7 OS {'OS': True, 'energy': -472.9575804143434, 'atomization': 0.20137881270121472, 'atomization_ev': 5.479796609541503, 'atomization_H': 0.20137881270121472, 'openshell': True, 'name': 'Sulfur monoxide'}
#
# 8 C2H {'C2H': True, 'energy': -76.51273529231412, 'atomization': 0.42356890230890987, 'atomization_ev': 11.525896908645244, 'atomization_H': 0.42356890230890987, 'openshell': True, 'name': 'Ethynyl radical'}
#
# 9 CF4 {'CF4': True, 'energy': -437.1194925791516, 'atomization': 0.7639345937792278, 'atomization_ev': 20.787719128694746, 'atomization_H': 0.7639345937792278, 'openshell': False, 'name': 'Tetrafluoromethane'}
#
# 10 CH4 {'CH4': True, 'energy': -40.46144804424925, 'atomization': 0.6695182791315805, 'atomization_ev': 18.218520343819495, 'atomization_H': 0.6695182791315805, 'openshell': False, 'name': 'Methane'}
#
# 11 CO2 {'CO2': True, 'energy': -188.40175875703355, 'atomization': 0.6223386877991182, 'atomization_ev': 16.934698271599974, 'atomization_H': 0.6223386877991182, 'openshell': False, 'name': 'Carbon dioxide'}
#
# 12 CS2 {'CS2': True, 'energy': -833.8515148107277, 'atomization': 0.4471796463688061, 'atomization_ev': 12.168377979581615, 'atomization_H': 0.4471796463688061, 'openshell': False, 'name': 'Carbon disulfide'}
#
# 13 F2O {'OF2': True, 'energy': -274.4141096724148, 'atomization': 0.14956391317051176, 'atomization_ev': 4.06984137659774, 'atomization_H': 0.14956391317051176, 'openshell': False, 'name': 'Difluorine monoxide'}
#
# 14 HBe {'BeH': True, 'energy': -15.213086658834586, 'atomization': 0.08093697552392216, 'atomization_ev': 2.2024072846262093, 'atomization_H': 0.08093697552392216, 'openshell': True, 'name': 'Beryllium monohydride'}
#
# 15 H2O {'H2O': True, 'energy': -76.36040174268352, 'atomization': 0.3713350349049067, 'atomization_ev': 10.1045409791693, 'atomization_H': 0.3713350349049067, 'openshell': False, 'name': 'Water'}
#
# 16 H2S {'H2S': True, 'energy': -399.09602128483544, 'atomization': 0.2927899850576444, 'atomization_ev': 7.96722130747228, 'atomization_H': 0.2927899850576444, 'openshell': False, 'name': 'Hydrogen sulfide'}
#
# 17 Cl2 {'Cl2': True, 'energy': -919.5958912237417, 'atomization': 0.09454200500963746, 'atomization_ev': 2.5726189938349067, 'atomization_H': 0.09454200500963746, 'openshell': False, 'name': 'Dichlorine'}
#
# 18 CHN {'CNH': True, 'energy': -93.32175404375893, 'atomization': 0.4993221026004529, 'atomization_ev': 13.58724648435963, 'atomization_H': 0.4993221026004529, 'openshell': False, 'name': 'Hydrogen cyanide'}
#
# 19 CHO {'CHO': True, 'energy': -113.73190487562901, 'atomization': 0.44547330448481937, 'atomization_ev': 12.121946051886907, 'atomization_H': 0.44547330448481937, 'openshell': True, 'name': 'Formyl radical'}
#
# 20 HCl {'HCl': True, 'energy': -460.42345395062125, 'atomization': 0.17123597861668197, 'atomization_ev': 4.659568315398828, 'atomization_H': 0.17123597861668197, 'openshell': False, 'name': 'Hydrogen chloride'}
#
# 21 N2O {'N2O': True, 'energy': -184.47901445619345, 'atomization': 0.43180352541868494, 'atomization_ev': 11.74997241685051, 'atomization_H': 0.43180352541868494, 'openshell': False, 'name': 'Nitrous oxide'}
#
# 22 F3N {'NF3': True, 'energy': -353.7744859564008, 'atomization': 0.3289583389200051, 'atomization_ev': 8.95141234628689, 'atomization_H': 0.3289583389200051, 'openshell': False, 'name': 'Trifluoroamine'}
#
# 23 NO2 {'NO2': True, 'energy': -204.87297985889361, 'atomization': 0.36339749810529004, 'atomization_ev': 9.888549601232311, 'atomization_H': 0.36339749810529004, 'openshell': True, 'name': 'Nitrogen dioxide'}
#
# 24 Li2 {'Li2': True, 'energy': -14.933280917716045, 'atomization': 0.03856027953902061, 'atomization_ev': 1.0492786517437995, 'atomization_H': 0.03856027953902061, 'openshell': False, 'name': 'Dilithium'}
#
# 25 FLi {'LiF': True, 'energy': -107.30594205221794, 'atomization': 0.22243004393513086, 'atomization_ev': 6.052629788935811, 'atomization_H': 0.22243004393513086, 'openshell': False, 'name': 'Lithium fluoride'}
#
# 26 HLi {'LiH': True, 'energy': -8.03807992441895, 'atomization': 0.09227576969496765, 'atomization_ev': 2.510951589865373, 'atomization_H': 0.09227576969496765, 'openshell': False, 'name': 'Lithium hydride'}
#
# 27 F3P {'PF3': True, 'energy': -640.4601109820627, 'atomization': 0.5830966332662726, 'atomization_ev': 15.866867577317441, 'atomization_H': 0.5830966332662726, 'openshell': False, 'name': 'Phosphorus trifluoride'}
#
# 28 H3P {'PH3': True, 'energy': -342.85719286124316, 'atomization': 0.38554185460863516, 'atomization_ev': 10.491128234306043, 'atomization_H': 0.38554185460863516, 'openshell': False, 'name': 'Phosphane'}
#
# 29 Na2 {'Na2': True, 'energy': -324.03216777703557, 'atomization': 0.027339558132268862, 'atomization_ev': 0.7439472700727967, 'atomization_H': 0.027339558132268862, 'openshell': False, 'name': 'Disodium'}
#
# 30 O2S {'SO2': True, 'energy': -548.1911792751569, 'atomization': 0.415772291066676, 'atomization_ev': 11.313740310450898, 'atomization_H': 0.415772291066676, 'openshell': False, 'name': 'Sulfur dioxide'}
#
# 31 OSi {'SiO': True, 'energy': -364.3822167697157, 'atomization': 0.30820419399624743, 'atomization_ev': 8.386663297160858, 'atomization_H': 0.30820419399624743, 'openshell': False, 'name': 'Silicon monoxide'}
#
# 32 C5H8 {'C5H8': True, 'energy': -195.01897143551344, 'atomization': 2.047903538295336, 'atomization_ev': 55.72629372122194, 'atomization_H': 2.047903538295336, 'openshell': False, 'name': 'Spiropentane'}
#
# 33 C3H4 {'C3H4': True, 'energy': -116.50314730067291, 'atomization': 1.1214817768537062, 'atomization_ev': 30.517073549259486, 'atomization_H': 1.1214817768537062, 'openshell': False, 'name': 'Allene'}
#
# 34 C2H3 {'C2H3': True, 'energy': -77.79784885898647, 'atomization': 0.7103105147956372, 'atomization_ev': 19.328533615271105, 'atomization_H': 0.7103105147956372, 'openshell': True, 'name': 'Vinyl radical'}
#
# 35 C2H5 {'C2H5': True, 'energy': -79.04870045828909, 'atomization': 0.9621063978502713, 'atomization_ev': 26.180248588417182, 'atomization_H': 0.9621063978502713, 'openshell': True, 'name': 'Ethyl radical'}
#
# 36 CCl4 {'CCl4': True, 'energy': -1877.3120220682092, 'atomization': 0.5023653328801524, 'atomization_ev': 13.670056998261575, 'atomization_H': 0.5023653328801524, 'openshell': False, 'name': 'Tetrachloromethane'}
#
# 37 CH3O {'CH3O': True, 'energy': -114.92299932985135, 'atomization': 0.6378443079100775, 'atomization_ev': 17.35662768598648, 'atomization_H': 0.6378443079100775, 'openshell': True, 'name': 'Methoxy radical'}
#
# 38 CH3S {'CH3S': True, 'energy': -437.70772142994866, 'atomization': 0.6098001219908945, 'atomization_ev': 16.593506517200467, 'atomization_H': 0.6098001219908945, 'openshell': True, 'name': 'Methylthio radical'}
#
# 39 CHF3 {'CHF3': True, 'energy': -337.94742829676886, 'atomization': 0.7330833231089329, 'atomization_ev': 19.948213293143112, 'atomization_H': 0.7330833231089329, 'openshell': False, 'name': 'Trifluoromethane'}
#
# 40 CF2O {'COF2': True, 'energy': -312.7375228886643, 'atomization': 0.6711484450386035, 'atomization_ev': 18.26287941759926, 'atomization_H': 0.6711484450386035, 'openshell': False, 'name': 'Carbonyl fluoride'}
#
# 41 AlF3 {'AlF3': True, 'energy': -541.6730028215618, 'atomization': 0.6886270229529224, 'atomization_ev': 18.738495748382775, 'atomization_H': 0.6886270229529224, 'openshell': False, 'name': 'Aluminum trifluoride'}
#
# 42 CH2O {'CH2O': True, 'energy': -114.382290917327, 'atomization': 0.5970025578609944, 'atomization_ev': 16.24526705949016, 'atomization_H': 0.5970025578609944, 'openshell': False, 'name': 'Formaldehyde'}
#
# 43 H2O2 {'H2O2': True, 'energy': -151.4069779786331, 'atomization': 0.42900024946642107, 'atomization_ev': 11.673691392780631, 'atomization_H': 0.42900024946642107, 'openshell': False, 'name': 'Hydrogen peroxide'}
#
# 44 ClF3 {'F3Cl': True, 'energy': -758.8671165747131, 'atomization': 0.20470008529683167, 'atomization_ev': 5.570173040232988, 'atomization_H': 0.20470008529683167, 'openshell': False, 'name': 'Chlorine trifluoride'}
#
# 45 ClNO {'NOCl': True, 'energy': -589.5755015004459, 'atomization': 0.3060103258596931, 'atomization_ev': 8.326965104410519, 'atomization_H': 0.3060103258596931, 'openshell': False, 'name': 'Nitrosyl chloride'}
#
# 46 HClO {'HOCl': True, 'energy': -535.5053804188752, 'atomization': 0.26485625430505877, 'atomization_ev': 7.207105776862933, 'atomization_H': 0.26485625430505877, 'openshell': False, 'name': 'Hypochlorous acid'}
#
# 47 ClNa {'NaCl': True, 'energy': -621.9090101929658, 'atomization': 0.1572881572346301, 'atomization_ev': 4.280028763572891, 'atomization_H': 0.1572881572346301, 'openshell': False, 'name': 'Sodium chloride'}
#
# 48 F4Si {'SiF4': True, 'energy': -688.5448164575241, 'atomization': 0.9216302924906136, 'atomization_ev': 25.078837660712576, 'atomization_H': 0.9216302924906136, 'openshell': False, 'name': 'Silicon tetrafluoride'}
#
# 49 H3Si {'SiH3': True, 'energy': -290.9497104122744, 'atomization': 0.3631461173813099, 'atomization_ev': 9.881709183313003, 'atomization_H': 0.3631461173813099, 'openshell': True, 'name': 'Silyl radical'}
#
# 50 H4Si {'SiH4': True, 'energy': -291.6020797140082, 'atomization': 0.5172006043938313, 'atomization_ev': 14.073745298196592, 'atomization_H': 0.5172006043938313, 'openshell': False, 'name': 'Silane'}
#
# 51 C3H7Cl {'C3H7Cl': True, 'energy': -578.2067730368547, 'atomization': 1.5733081578172978, 'atomization_ev': 42.81189561765259, 'atomization_H': 1.5733081578172978, 'openshell': False, 'name': '1-Chloropropane'}
#
# 52 H4N2 {'N2H4': True, 'energy': -111.75021564212388, 'atomization': 0.6980347561079383, 'atomization_ev': 18.99449320687815, 'atomization_H': 0.6980347561079383, 'openshell': False, 'name': 'Hydrazine'}
#
# 53 CH2O2 {'CH2O2': True, 'energy': -189.57625599052105, 'atomization': 0.8002057852104896, 'atomization_ev': 21.77470852029453, 'atomization_H': 0.8002057852104896, 'openshell': False, 'name': 'Formic acid'}
#
# 54 C2H4 {'C2H4': True, 'energy': -78.48484990051807, 'atomization': 0.898400428315536, 'atomization_ev': 24.446720859350922, 'atomization_H': 0.898400428315536, 'openshell': False, 'name': 'Ethylene'}
#
# 55 C4H8 {'C4H8': True, 'energy': -157.0069871842038, 'atomization': 1.832485493039713, 'atomization_ev': 49.864470135156566, 'atomization_H': 1.832485493039713, 'openshell': False, 'name': 'Cyclobutane'}
#
# 56 C4H6 {'C4H6': True, 'energy': -155.77115487317982, 'atomization': 1.5957762622227383, 'atomization_ev': 43.42328387986482, 'atomization_H': 1.5957762622227383, 'openshell': False, 'name': 'Cyclobutene'}
#
# 57 C2H6OS {'C2H6OS': True, 'energy': -552.739977936297, 'atomization': 1.3664637187689381, 'atomization_ev': 37.18337173971398, 'atomization_H': 1.3664637187689381, 'openshell': False, 'name': 'Dimethyl sulfoxide'}
#
# 58 H3N {'NH3': True, 'energy': -56.49996876841539, 'atomization': 0.47457252768494956, 'atomization_ev': 12.913776247394873, 'atomization_H': 0.47457252768494956, 'openshell': False, 'name': 'Ammonia'}
#
# 59 C2H6 {'C2H6': True, 'energy': -79.72083297566085, 'atomization': 1.1356466997701047, 'atomization_ev': 30.90252073474301, 'atomization_H': 1.1356466997701047, 'openshell': False, 'name': 'Ethane'}
#
# 60 C2F3N {'C2NF3': True, 'energy': -430.0650757453127, 'atomization': 1.023907967960914, 'atomization_ev': 27.86195496960988, 'atomization_H': 1.023907967960914, 'openshell': False, 'name': 'Trifluoroacetonitril'}
#
# 61 BCl3 {'BCl3': True, 'energy': -1404.3915509167396, 'atomization': 0.5179471289680754, 'atomization_ev': 14.094059266563026, 'atomization_H': 0.5179471289680754, 'openshell': False, 'name': 'Boron trichloride'}
#
# 62 CH2F2 {'CH2F2': True, 'energy': -238.77158091102544, 'atomization': 0.6980995056883574, 'atomization_ev': 18.99625513270585, 'atomization_H': 0.6980995056883574, 'openshell': False, 'name': 'Difluoromethane'}
#
# 63 C2H3O {'C2H3O': True, 'energy': -153.00785732844284, 'atomization': 0.9280785889405901, 'atomization_ev': 25.254304744612448, 'atomization_H': 0.9280785889405901, 'openshell': True, 'name': 'Carbonyl methane'}
#
# 64 CH3Cl {'CH3Cl': True, 'energy': -499.67593144029075, 'atomization': 0.6308018388397842, 'atomization_ev': 17.164992341550064, 'atomization_H': 0.6308018388397842, 'openshell': False, 'name': 'Chloromethane'}
#
# 65 CH4S {'CH4S': True, 'energy': -438.3526304040656, 'atomization': 0.7570482854617101, 'atomization_ev': 20.600333134783963, 'atomization_H': 0.7570482854617101, 'openshell': False, 'name': 'Thiomethanol'}
#
# 66 CHCl3 {'CHCl3': True, 'energy': -1418.1041011095742, 'atomization': 0.5501733760225651, 'atomization_ev': 14.970980115279373, 'atomization_H': 0.5501733760225651, 'openshell': False, 'name': 'Trichloromethane'}
#
# 67 AlCl3 {'AlCl3': True, 'energy': -1621.8315420914016, 'atomization': 0.4992192650315519, 'atomization_ev': 13.584448131574458, 'atomization_H': 0.4992192650315519, 'openshell': False, 'name': 'Aluminum trichloride'}
#
# 68 CH3O {'CH3O': True, 'energy': -114.93785210967981, 'atomization': 0.6533880160095189, 'atomization_ev': 17.779593527330462, 'atomization_H': 0.6533880160095189, 'openshell': True, 'name': 'Hydroxymethyl radical'}
#
# 69 C4H4O {'C4H4O': True, 'energy': -229.75394389787004, 'atomization': 1.586170471527617, 'atomization_ev': 43.161897001190596, 'atomization_H': 1.586170471527617, 'openshell': False, 'name': 'Furan'}
#
# 70 C3H8O {'C3H8O': True, 'energy': -194.11792244748355, 'atomization': 1.7471417372484415, 'atomization_ev': 47.54214825155095, 'atomization_H': 1.7471417372484415, 'openshell': False, 'name': 'Methoxyethane'}
#
# 71 C6H6 {'C6H6': True, 'energy': -231.9459775749353, 'atomization': 2.181607613062008, 'atomization_ev': 59.3645669127287, 'atomization_H': 2.181607613062008, 'openshell': False, 'name': 'Benzene'}
#
# 72 COS {'COS': True, 'energy': -511.1271984867349, 'atomization': 0.5357989691695165, 'atomization_ev': 14.579832581529757, 'atomization_H': 0.5357989691695165, 'openshell': False, 'name': 'Carbonyl sulfide'}
#
# 73 C2H6S {'C2H6S': True, 'energy': -477.6168484976927, 'atomization': 1.227309252850515, 'atomization_ev': 33.396785850593105, 'atomization_H': 1.227309252850515, 'openshell': False, 'name': 'Thioethanol'}
#
# 74 H6Si2 {'Si2H6': True, 'energy': -582.0226331505271, 'atomization': 0.8533766171311462, 'atomization_ev': 23.221560552924267, 'atomization_H': 0.8533766171311462, 'openshell': False, 'name': 'Disilane'}
#
# 75 Cl4Si {'SiCl4': True, 'energy': -2128.7072254403247, 'atomization': 0.6199048653351282, 'atomization_ev': 16.868470589017566, 'atomization_H': 0.6199048653351282, 'openshell': False, 'name': 'Silicon tetrachloride'}
#
# 76 C4H9 {'C4H9': True, 'energy': -157.5847076419825, 'atomization': 1.910733456576817, 'atomization_ev': 51.993705676585314, 'atomization_H': 1.910733456576817, 'openshell': True, 'name': 'tert-Butyl radical'}
#
# 77 C2H2O {'C2H2O': True, 'energy': -152.43040949483597, 'atomization': 0.8501429469090375, 'atomization_ev': 23.133567904234965, 'atomization_H': 0.8501429469090375, 'openshell': False, 'name': 'Ketene'}
#
# 78 C4H10 {'C4H10': True, 'energy': -158.2474751234166, 'atomization': 2.074736526180797, 'atomization_ev': 56.456456512760376, 'atomization_H': 2.074736526180797, 'openshell': False, 'name': 'n-Butane'}
#
# 79 C2H4O2 {'C2H4O2': True, 'energy': -228.8508717941311, 'atomization': 1.2811885213569338, 'atomization_ev': 34.8629154246318, 'atomization_H': 1.2811885213569338, 'openshell': False, 'name': 'Acetic acid'}
#
# 80 ClF {'FCl': True, 'energy': -559.4894233328325, 'atomization': 0.09995430817290774, 'atomization_ev': 2.719895264491558, 'atomization_H': 0.09995430817290774, 'openshell': False, 'name': 'Chlorine monofluoride'}
#
# 81 C2H4O {'C2H4O': True, 'energy': -153.65840900405297, 'atomization': 1.0799582518107982, 'atomization_ev': 29.38716088022443, 'atomization_H': 1.0799582518107982, 'openshell': False, 'name': 'Acetaldehyde'}
#
# 82 C2H4O {'C2H4O': True, 'energy': -153.61647300277895, 'atomization': 1.0380919348715534, 'atomization_ev': 28.24792036857214, 'atomization_H': 1.0380919348715534, 'openshell': False, 'name': 'Oxirane'}
#
# 83 NO {'NO': True, 'energy': -129.76327396316532, 'atomization': 0.24348889276674332, 'atomization_ev': 6.625670253721614, 'atomization_H': 0.24348889276674332, 'openshell': True, 'name': 'Nitric oxide'}
#
# 84 HN {'NH': True, 'energy': -55.092418339986715, 'atomization': 0.132172937629701, 'atomization_ev': 3.5966088278164094, 'atomization_H': 0.132172937629701, 'openshell': True, 'name': 'Imidogen'}
#
# 85 C2H4O2 {'C2H4O2': True, 'energy': -228.8242969783602, 'atomization': 1.2540889175521006, 'atomization_ev': 34.125497644391075, 'atomization_H': 1.2540889175521006, 'openshell': False, 'name': 'Methyl formate'}
#
# 86 C4H6 {'C4H6': True, 'energy': -155.77536098146916, 'atomization': 1.6001449545016064, 'atomization_ev': 43.54216205188677, 'atomization_H': 1.6001449545016064, 'openshell': False, 'name': '2-Butyne'}
#
# 87 CH5N {'CNH5': True, 'energy': -95.74676196338788, 'atomization': 0.9274006227456133, 'atomization_ev': 25.23585634476946, 'atomization_H': 0.9274006227456133, 'openshell': False, 'name': 'Methylamine'}
#
# 88 ClO {'OCl': True, 'energy': -534.8450994493151, 'atomization': 0.1032946247627656, 'atomization_ev': 2.8107899086617785, 'atomization_H': 0.1032946247627656, 'openshell': True, 'name': 'Monochlorine monoxide'}
#
# 89 C3H8 {'C3H8': True, 'energy': -118.98403117403127, 'atomization': 1.6051306721938798, 'atomization_ev': 43.67783034061974, 'atomization_H': 1.6051306721938798, 'openshell': False, 'name': 'Propane'}
#
# 90 C3H6 {'C3H6': True, 'energy': -117.75221239147405, 'atomization': 1.3721845346389114, 'atomization_ev': 37.33904306872614, 'atomization_H': 1.3721845346389114, 'openshell': False, 'name': 'Propene'}
#
# 91 C3H4 {'C3H4': True, 'energy': -116.50529425091469, 'atomization': 1.123786100156858, 'atomization_ev': 30.579777380186496, 'atomization_H': 1.123786100156858, 'openshell': False, 'name': 'Propyne'}
#
# 92 C4H6 {'C4H6': True, 'energy': -155.75865007630978, 'atomization': 1.5824835542425744, 'atomization_ev': 43.06157087170739, 'atomization_H': 1.5824835542425744, 'openshell': False, 'name': 'Methylenecyclopropane'}
#
# 93 H2Si {'SiH2': True, 'energy': -290.3330847545195, 'atomization': 0.24494766272559804, 'atomization_ev': 6.66536540619276, 'atomization_H': 0.24494766272559804, 'openshell': True, 'name': 'Singlet silylene'}
#
# 94 H2Si {'SiH2': True, 'energy': -290.317342678, 'atomization': 0.21166256959131305, 'atomization_ev': 5.759631888058715, 'atomization_H': 0.21166256959131305, 'openshell': True, 'name': 'Triplet silylene'}
#
# 95 C2H4S {'C2H4S': True, 'energy': -476.3886135166165, 'atomization': 0.9981223997587044, 'atomization_ev': 27.160293919401905, 'atomization_H': 0.9981223997587044, 'openshell': False, 'name': 'Thiirane'}
#
# 96 CH3NO2 {'CNH3O2': True, 'energy': -244.76206876133506, 'atomization': 0.9592079019268026, 'atomization_ev': 26.101376496953623, 'atomization_H': 0.9592079019268026, 'openshell': False, 'name': 'Nitromethane'}
#
# 97 C3H7 {'C3H7': True, 'energy': -118.31589531463287, 'atomization': 1.4358714601794056, 'atomization_ev': 39.07205258431367, 'atomization_H': 1.4358714601794056, 'openshell': True, 'name': 'Isopropyl radical'}
#
# 98 C2H5NO {'C2NH5O': True, 'energy': -208.98962217646053, 'atomization': 1.3840146638613726, 'atomization_ev': 37.660957281716684, 'atomization_H': 1.3840146638613726, 'openshell': False, 'name': 'Acetamide'}
#
# 99 C4H5N {'C4NH5': True, 'energy': -209.91383785297293, 'atomization': 1.709746950156965, 'atomization_ev': 46.52458426470576, 'atomization_H': 1.709746950156965, 'openshell': False, 'name': 'Pyrrole'}
#
# 100 C2H3FO {'C2H3OF': True, 'energy': -252.8458873000209, 'atomization': 1.1266084201033628, 'atomization_ev': 30.656576617735105, 'atomization_H': 1.1266084201033628, 'openshell': False, 'name': 'Acetyl fluoride'}
#
# 101 C2H2 {'C2H2': True, 'energy': -77.23364708420903, 'atomization': 0.6458922998762915, 'atomization_ev': 17.575624702100136, 'atomization_H': 0.6458922998762915, 'openshell': False, 'name': 'Acetylene'}
#
# 102 C2H3F {'C2H3F': True, 'energy': -177.6415004162453, 'atomization': 0.9143440602940367, 'atomization_ev': 24.88056918374835, 'atomization_H': 0.9143440602940367, 'openshell': False, 'name': 'Vinyl fluoride'}
#
# 103 C2N2 {'C2N2': True, 'energy': -185.44907204111655, 'atomization': 0.7999239340957237, 'atomization_ev': 21.76703896080924, 'atomization_H': 0.7999239340957237, 'openshell': False, 'name': 'Cyanogen'}
#
# 104 C2H5Cl {'C2H5Cl': True, 'energy': -538.9429458142945, 'atomization': 1.1036375542499617, 'atomization_ev': 30.03150751968425, 'atomization_H': 1.1036375542499617, 'openshell': False, 'name': 'Ethyl chloride'}
#
# 105 CH2 {'CH2': True, 'energy': -39.08309334882895, 'atomization': 0.28849746875574045, 'atomization_ev': 7.850415989365281, 'atomization_H': 0.28849746875574045, 'openshell': True, 'name': 'Singlet carbene'}
#
# 106 CH2 {'CH2': True, 'energy': -39.06484363664457, 'atomization': 0.3036488705738187, 'atomization_ev': 8.262706633047307, 'atomization_H': 0.3036488705738187, 'openshell': True, 'name': 'Triplet carbene'}
#
# 107 HO {'HO': True, 'energy': -75.66221512476179, 'atomization': 0.1707484523641144, 'atomization_ev': 4.646302050343198, 'atomization_H': 0.1707484523641144, 'openshell': True, 'name': 'Hydroxyl radical'}
#
# 108 CH {'CH': True, 'energy': -38.43074470234005, 'atomization': 0.13391736750216957, 'atomization_ev': 3.644077182468589, 'atomization_H': 0.13391736750216957, 'openshell': True, 'name': 'Methylidyne radical'}
#
# 109 C5H5N {'C5NH5': True, 'energy': -247.97424390475274, 'atomization': 1.974458470105793, 'atomization_ev': 53.7277516191303, 'atomization_H': 1.974458470105793, 'openshell': False, 'name': 'Pyridine'}
#
# 110 Si2 {'Si2': True, 'energy': -578.2652982175696, 'atomization': 0.11721578455288022, 'atomization_ev': 3.1896039616174865, 'atomization_H': 0.11721578455288022, 'openshell': True, 'name': 'Disilicon'}
#
# 111 C3H6 {'C3H6': True, 'energy': -117.74110805127793, 'atomization': 1.3602363326521565, 'atomization_ev': 37.01391593216744, 'atomization_H': 1.3602363326521565, 'openshell': False, 'name': 'Cyclopropane'}
#
# 112 C3H4 {'C3H4': True, 'energy': -116.46863049566645, 'atomization': 1.0863646514734446, 'atomization_ev': 29.56148789447108, 'atomization_H': 1.0863646514734446, 'openshell': False, 'name': 'Cyclopropene'}
#
# 113 N2 {'N2': True, 'energy': -109.41916258352211, 'atomization': 0.36405261150717777, 'atomization_ev': 9.906376144900815, 'atomization_H': 0.36405261150717777, 'openshell': False, 'name': 'Dinitrogen'}
#
# 114 F2 {'F2': True, 'energy': -199.3364659725311, 'atomization': 0.06182061410488379, 'atomization_ev': 1.6822245946714354, 'atomization_H': 0.06182061410488379, 'openshell': False, 'name': 'Difluorine'}
#
# 115 CH6Si {'SiCH6': True, 'energy': -330.8793140340968, 'atomization': 1.002300652095163, 'atomization_ev': 27.27398995663649, 'atomization_H': 1.002300652095163, 'openshell': False, 'name': 'Methylsilane'}
#
# 116 CH3 {'CH3': True, 'energy': -39.78388688523675, 'atomization': 0.4902723965371663, 'atomization_ev': 13.340991439264483, 'atomization_H': 0.4902723965371663, 'openshell': True, 'name': 'Methyl radical'}
#
# 117 H2P {'PH2': True, 'energy': -342.2195377081545, 'atomization': 0.2458465392537696, 'atomization_ev': 6.689825082389079, 'atomization_H': 0.2458465392537696, 'openshell': True, 'name': 'Phosphino radical'}
#
# 118 C3H9N {'C3NH9': True, 'energy': -174.25780650811467, 'atomization': 1.8502954364538242, 'atomization_ev': 50.34910338047008, 'atomization_H': 1.8502954364538242, 'openshell': False, 'name': 'Trimethylamine'}
#
# 119 C2H6O {'C2H6O': True, 'energy': -154.86904521012679, 'atomization': 1.292317831591329, 'atomization_ev': 35.16575938160487, 'atomization_H': 1.292317831591329, 'openshell': False, 'name': 'Ethanol'}
#
# 120 C2H7N {'C2NH7': True, 'energy': -135.00006782744526, 'atomization': 1.3866122646758345, 'atomization_ev': 37.731641600216214, 'atomization_H': 1.3866122646758345, 'openshell': False, 'name': 'Dimethylamine'}
#
# 121 O2 {'O2': True, 'energy': -150.12619657260885, 'atomization': 0.19267951613196113, 'atomization_ev': 5.24307669245509, 'atomization_H': 0.19267951613196113, 'openshell': True, 'name': 'Dioxygen'}
#
# 122 H2N {'NH2': True, 'energy': -55.81843551814929, 'atomization': 0.29059230812224196, 'atomization_ev': 7.907419472026195, 'atomization_H': 0.29059230812224196, 'openshell': True, 'name': 'Amino radical'}
#
# 123 C2F4 {'C2F4': True, 'energy': -475.0919358474079, 'atomization': 0.9411199161967742, 'atomization_ev': 25.60917733485057, 'atomization_H': 0.9411199161967742, 'openshell': False, 'name': 'Tetrafluoroethylene'}
#
# 124 CH4O {'CH4O': True, 'energy': -115.60123375195084, 'atomization': 0.8180690518084752, 'atomization_ev': 22.260792763348505, 'atomization_H': 0.8180690518084752, 'openshell': False, 'name': 'Methanol'}
#
# 125 C4H6 {'C4H6': True, 'energy': -155.78889973138988, 'atomization': 1.6140661142917205, 'atomization_ev': 43.92097610484247, 'atomization_H': 1.6140661142917205, 'openshell': False, 'name': '1,3-Butadiene'}
#
# 126 C2H5O {'C2H5O': True, 'energy': -154.1904691977908, 'atomization': 1.1118378981701031, 'atomization_ev': 30.254650243627793, 'atomization_H': 1.1118378981701031, 'openshell': True, 'name': 'Ethoxy radical'}
#
# 127 C2H6S {'C2H6S': True, 'energy': -477.61358467567106, 'atomization': 1.2255114997941716, 'atomization_ev': 33.34786649820046, 'atomization_H': 1.2255114997941716, 'openshell': False, 'name': 'Dimethyl sulfide'}
#
# 128 C2H5N {'C2NH5': True, 'energy': -133.76243415075217, 'atomization': 1.1475682401649225, 'atomization_ev': 31.226922372431485, 'atomization_H': 1.1475682401649225, 'openshell': False, 'name': 'Aziridine'}
#
# 129 C4H6 {'C4H6': True, 'energy': -155.74844507697676, 'atomization': 1.5713656704047234, 'atomization_ev': 42.759037842821556, 'atomization_H': 1.5713656704047234, 'openshell': False, 'name': 'Bicyclo[1.1.0]butane'}
#
# 130 C3H3N {'C3NH3': True, 'energy': -170.62716215276137, 'atomization': 1.2155629172027136, 'atomization_ev': 33.077151776909, 'atomization_H': 1.2155629172027136, 'openshell': False, 'name': 'Acrylonitrile'}
#
# 131 C3H8O {'C3H8O': True, 'energy': -194.13845204465352, 'atomization': 1.767682589436701, 'atomization_ev': 48.10109330971515, 'atomization_H': 1.767682589436701, 'openshell': False, 'name': 'Isopropyl alcohol'}
#
# 132 C4H4S {'C4H4S': True, 'energy': -552.5171908991917, 'atomization': 1.5381796060404913, 'atomization_ev': 41.855999034776936, 'atomization_H': 1.5381796060404913, 'openshell': False, 'name': 'Thiophene'}
#
# 133 BF3 {'BF3': True, 'energy': -324.28084069398125, 'atomization': 0.7512093968274431, 'atomization_ev': 20.441448882203634, 'atomization_H': 0.7512093968274431, 'openshell': False, 'name': 'Boron trifluoride'}
#
# 134 C2Cl4 {'C2Cl4': True, 'energy': -1915.3583458347077, 'atomization': 0.752835753935618, 'atomization_ev': 20.485704313287652, 'atomization_H': 0.752835753935618, 'openshell': False, 'name': 'Tetrachloroethylene'}
#
# 135 C4H10 {'C4H10': True, 'energy': -158.25011052944797, 'atomization': 2.077006570294315, 'atomization_ev': 56.518227559425654, 'atomization_H': 2.077006570294315, 'openshell': False, 'name': 'Isobutane'}
#
# 136 C4H8 {'C4H8': True, 'energy': -157.0211689068756, 'atomization': 1.8471646038006164, 'atomization_ev': 50.26390908456595, 'atomization_H': 1.8471646038006164, 'openshell': False, 'name': 'Isobutene'}
#
# 137 CH3NO2 {'CNH3O2': True, 'energy': -244.75762133231325, 'atomization': 0.9552238983316016, 'atomization_ev': 25.99296623720214, 'atomization_H': 0.9552238983316016, 'openshell': False, 'name': 'Methyl nitrite'}
#
# 138 C3H6O {'C3H6O': True, 'energy': -192.93276114269554, 'atomization': 1.5606134312562985, 'atomization_ev': 42.46645451272745, 'atomization_H': 1.5606134312562985, 'openshell': False, 'name': 'Acetone'}
#
# 139 C2H2O2 {'C2H2O2': True, 'energy': -227.58433120125275, 'atomization': 1.012268278680862, 'atomization_ev': 27.545222891406695, 'atomization_H': 1.012268278680862, 'openshell': False, 'name': 'Glyoxal'}
#
# 140 C2H3ClO {'C2H3OCl': True, 'energy': -612.8984899313568, 'atomization': 1.0660332832218353, 'atomization_ev': 29.008243184572976, 'atomization_H': 1.0660332832218353, 'openshell': False, 'name': 'Acetyl chloride'}
#
# 141 CN {'CN': True, 'energy': -92.6097702595823, 'atomization': 0.2889202454278889, 'atomization_ev': 7.86192032859321, 'atomization_H': 0.2889202454278889, 'openshell': True, 'name': 'Cyano radical'}
#
# 142 C2H7N {'C2NH7': True, 'energy': -135.0125588973631, 'atomization': 1.399684062322804, 'atomization_ev': 38.08734333202032, 'atomization_H': 1.399684062322804, 'openshell': False, 'name': 'Ethylamine'}
#
# 143 C2H3Cl {'C2H3Cl': True, 'energy': -537.7074076335418, 'atomization': 0.867073057789218, 'atomization_ev': 23.594259686830895, 'atomization_H': 0.867073057789218, 'openshell': False, 'name': 'Vinyl chloride'}
#
# 144 O3 {'O3': True, 'energy': -225.20206707949416, 'atomization': 0.2345382154735096, 'atomization_ev': 6.382109918715892, 'atomization_H': 0.2345382154735096, 'openshell': False, 'name': 'Ozone'}
#
# 145 C2H3N {'C2NH3': True, 'energy': -132.5986576857774, 'atomization': 0.9822397085617747, 'atomization_ev': 26.72810387813643, 'atomization_H': 0.9822397085617747, 'openshell': False, 'name': 'Acetonitrile'}
#
# 146 CH2Cl2 {'CH2Cl2': True, 'energy': -958.8912062842795, 'atomization': 0.5920473105595063, 'atomization_ev': 16.110427912323164, 'atomization_H': 0.5920473105595063, 'openshell': False, 'name': 'Dichloromethane'}
#
# 147 C2H6O {'C2H6O': True, 'energy': -154.84971829779465, 'atomization': 1.272732987913964, 'atomization_ev': 34.6328286400732, 'atomization_H': 1.272732987913964, 'openshell': False, 'name': 'Dimethyl ether'}

# %%
#S2, C2H2, BeH, NO2, CH4, PF3, CH2, C2H4O2
g2inds = [5, 101, 14, 23, 10, 27, 105, 85]

# %%
for idx, at in enumerate(bh76):
    print(idx, at.get_chemical_formula(), at.info)
# Out:
# 0 C2H5 {'': True, 'name': 'C2H5', 'dirname': 'C2H5', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 2, 'spin': 1}
# 1 C2H6 {'': True, 'name': 'C2H6', 'dirname': 'C2H6', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 1, 'spin': 0}
# 2 C5H8 {'': True, 'name': 'C5H8', 'dirname': 'C5H8', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 1, 'spin': 0}
# 3 CH3O {'': True, 'name': 'CH2OH', 'dirname': 'CH2OH', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 2, 'spin': 1}
# 4 CH4 {'': True, 'name': 'CH4', 'dirname': 'CH4', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 1, 'spin': 0}
# 5 H2 {'': True, 'name': 'H2', 'dirname': 'H2', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 1, 'spin': 0}
# 6 H2O {'': True, 'name': 'H2O', 'dirname': 'H2O', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 1, 'spin': 0}
# 7 H2S {'': True, 'name': 'H2S', 'dirname': 'H2S', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 1, 'spin': 0}
# 8 HS {'': True, 'name': 'HS', 'dirname': 'HS', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 2, 'spin': 1}
# 9 HN2 {'': True, 'name': 'N2H', 'dirname': 'N2H', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 2, 'spin': 1}
# 10 H2N2 {'': True, 'name': 'N2H2', 'dirname': 'N2H2', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 1, 'spin': 0}
# 11 HN {'': True, 'name': 'NH', 'dirname': 'NH', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 3, 'spin': 2}
# 12 H2N {'': True, 'name': 'NH2', 'dirname': 'NH2', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 2, 'spin': 1}
# 13 H3N {'': True, 'name': 'NH3', 'dirname': 'NH3', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 1, 'spin': 0}
# 14 O {'': True, 'name': 'O', 'dirname': 'O', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 3, 'spin': 2}
# 15 H2P {'': True, 'name': 'PH2', 'dirname': 'PH2', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 2, 'spin': 1}
# 16 H3P {'': True, 'name': 'PH3', 'dirname': 'PH3', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 1, 'spin': 0}
# 17 H2Cl {'': True, 'name': 'RKT01', 'dirname': 'RKT01', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 2, 'spin': 1}
# 18 H3O {'': True, 'name': 'RKT02', 'dirname': 'RKT02', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 2, 'spin': 1}
# 19 CH5 {'': True, 'name': 'RKT03', 'dirname': 'RKT03', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 2, 'spin': 1}
# 20 CH5O {'': True, 'name': 'RKT04', 'dirname': 'RKT04', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 2, 'spin': 1}
# 21 CH5O {'': True, 'name': 'RKT05', 'dirname': 'RKT05', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 2, 'spin': 1}
# 22 H3 {'': True, 'name': 'RKT06', 'dirname': 'RKT06', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 2, 'spin': 1}
# 23 H4NO {'': True, 'name': 'RKT07', 'dirname': 'RKT07', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 2, 'spin': 1}
# 24 CH4Cl {'': True, 'name': 'RKT08', 'dirname': 'RKT08', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 2, 'spin': 1}
# 25 C2H7O {'': True, 'name': 'RKT09', 'dirname': 'RKT09', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 2, 'spin': 1}
# 26 H2F {'': True, 'name': 'RKT10', 'dirname': 'RKT10', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 2, 'spin': 1}
# 27 CH4O {'': True, 'name': 'RKT11', 'dirname': 'RKT11', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 3, 'spin': 2}
# 28 H4P {'': True, 'name': 'RKT12', 'dirname': 'RKT12', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 2, 'spin': 1}
# 29 H2Cl {'': True, 'name': 'RKT13', 'dirname': 'RKT13', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 2, 'spin': 1}
# 30 H2O {'': True, 'name': 'RKT14', 'dirname': 'RKT14', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 3, 'spin': 2}
# 31 H3N2 {'': True, 'name': 'RKT15', 'dirname': 'RKT15', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 2, 'spin': 1}
# 32 H3S {'': True, 'name': 'RKT16', 'dirname': 'RKT16', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 2, 'spin': 1}
# 33 HClO {'': True, 'name': 'RKT17', 'dirname': 'RKT17', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 3, 'spin': 2}
# 34 CH5N {'': True, 'name': 'RKT18', 'dirname': 'RKT18', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 3, 'spin': 2}
# 35 C2H7N {'': True, 'name': 'RKT19', 'dirname': 'RKT19', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 3, 'spin': 2}
# 36 C2H8N {'': True, 'name': 'RKT20', 'dirname': 'RKT20', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 2, 'spin': 1}
# 37 CH6N {'': True, 'name': 'RKT21', 'dirname': 'RKT21', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 2, 'spin': 1}
# 38 C5H8 {'': True, 'name': 'RKT22', 'dirname': 'RKT22', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 1, 'spin': 0}
# 39 C2H4 {'': True, 'name': 'c2h4', 'dirname': 'c2h4', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 1, 'spin': 0}
# 40 C2H5 {'': True, 'name': 'c2h5', 'dirname': 'c2h5', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 2, 'spin': 1}
# 41 C2H5 {'': True, 'name': 'c2h5ts', 'dirname': 'c2h5ts', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 2, 'spin': 1}
# 42 C3H7 {'': True, 'name': 'c3h7', 'dirname': 'c3h7', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 2, 'spin': 1}
# 43 C3H7 {'': True, 'name': 'c3h7ts', 'dirname': 'c3h7ts', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 2, 'spin': 1}
# 44 CH3 {'': True, 'name': 'ch3', 'dirname': 'ch3', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 2, 'spin': 1}
# 45 CH3Cl {'': True, 'name': 'ch3cl', 'dirname': 'ch3cl', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 1, 'spin': 0}
# 46 CH3F {'': True, 'name': 'ch3f', 'dirname': 'ch3f', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 1, 'spin': 0}
# 47 CH3ClF {'': True, 'name': 'ch3fclts', 'dirname': 'ch3fclts', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 2, 'spin': 1}
# 48 CH4O {'': True, 'name': 'ch3oh', 'dirname': 'ch3oh', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 1, 'spin': 0}
# 49 Cl {'': True, 'name': 'cl', 'dirname': 'cl', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 2, 'spin': 1}
# 50 Cl {'': True, 'name': 'cl-', 'dirname': 'cl-', 'dataset': 'bh76', 'charge': -1, 'multiplicity': 1, 'spin': 0}
# 51 CH3Cl2 {'': True, 'name': 'clch3clcomp', 'dirname': 'clch3clcomp', 'dataset': 'bh76', 'charge': -1, 'multiplicity': 1, 'spin': 0}
# 52 CH3Cl2 {'': True, 'name': 'clch3clts', 'dirname': 'clch3clts', 'dataset': 'bh76', 'charge': -1, 'multiplicity': 1, 'spin': 0}
# 53 ClF {'': True, 'name': 'clf', 'dirname': 'clf', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 1, 'spin': 0}
# 54 CO {'': True, 'name': 'co', 'dirname': 'co', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 1, 'spin': 0}
# 55 F {'': True, 'name': 'f', 'dirname': 'f', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 2, 'spin': 1}
# 56 F {'': True, 'name': 'f-', 'dirname': 'f-', 'dataset': 'bh76', 'charge': -1, 'multiplicity': 1, 'spin': 0}
# 57 F2 {'': True, 'name': 'f2', 'dirname': 'f2', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 1, 'spin': 0}
# 58 CH3ClF {'': True, 'name': 'fch3clcomp1', 'dirname': 'fch3clcomp1', 'dataset': 'bh76', 'charge': -1, 'multiplicity': 1, 'spin': 0}
# 59 CH3ClF {'': True, 'name': 'fch3clcomp2', 'dirname': 'fch3clcomp2', 'dataset': 'bh76', 'charge': -1, 'multiplicity': 1, 'spin': 0}
# 60 CH3ClF {'': True, 'name': 'fch3clts', 'dirname': 'fch3clts', 'dataset': 'bh76', 'charge': -1, 'multiplicity': 1, 'spin': 0}
# 61 CH3F2 {'': True, 'name': 'fch3fcomp', 'dirname': 'fch3fcomp', 'dataset': 'bh76', 'charge': -1, 'multiplicity': 1, 'spin': 0}
# 62 CH3F2 {'': True, 'name': 'fch3fts', 'dirname': 'fch3fts', 'dataset': 'bh76', 'charge': -1, 'multiplicity': 1, 'spin': 0}
# 63 H {'': True, 'name': 'h', 'dirname': 'h', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 2, 'spin': 1}
# 64 CH4Cl {'': True, 'name': 'hch3clts', 'dirname': 'hch3clts', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 2, 'spin': 1}
# 65 HCl {'': True, 'name': 'hcl', 'dirname': 'hcl', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 1, 'spin': 0}
# 66 H2Cl {'': True, 'name': 'hclhts', 'dirname': 'hclhts', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 2, 'spin': 1}
# 67 CHN {'': True, 'name': 'hcn', 'dirname': 'hcn', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 1, 'spin': 0}
# 68 CHN {'': True, 'name': 'hcnts', 'dirname': 'hcnts', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 1, 'spin': 0}
# 69 CHO {'': True, 'name': 'hco', 'dirname': 'hco', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 2, 'spin': 1}
# 70 CHO {'': True, 'name': 'hcots', 'dirname': 'hcots', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 2, 'spin': 1}
# 71 HF {'': True, 'name': 'hf', 'dirname': 'hf', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 1, 'spin': 0}
# 72 HF2 {'': True, 'name': 'hf2ts', 'dirname': 'hf2ts', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 2, 'spin': 1}
# 73 CH4F {'': True, 'name': 'hfch3ts', 'dirname': 'hfch3ts', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 2, 'spin': 1}
# 74 H2F {'': True, 'name': 'hfhts', 'dirname': 'hfhts', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 2, 'spin': 1}
# 75 HN2 {'': True, 'name': 'hn2', 'dirname': 'hn2', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 2, 'spin': 1}
# 76 HN2 {'': True, 'name': 'hn2ts', 'dirname': 'hn2ts', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 2, 'spin': 1}
# 77 CHN {'': True, 'name': 'hnc', 'dirname': 'hnc', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 1, 'spin': 0}
# 78 CH4FO {'': True, 'name': 'hoch3fcomp1', 'dirname': 'hoch3fcomp1', 'dataset': 'bh76', 'charge': -1, 'multiplicity': 1, 'spin': 0}
# 79 CH4FO {'': True, 'name': 'hoch3fcomp2', 'dirname': 'hoch3fcomp2', 'dataset': 'bh76', 'charge': -1, 'multiplicity': 1, 'spin': 0}
# 80 CH4FO {'': True, 'name': 'hoch3fts', 'dirname': 'hoch3fts', 'dataset': 'bh76', 'charge': -1, 'multiplicity': 1, 'spin': 0}
# 81 N2 {'': True, 'name': 'n2', 'dirname': 'n2', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 1, 'spin': 0}
# 82 N2O {'': True, 'name': 'n2o', 'dirname': 'n2o', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 1, 'spin': 0}
# 83 HN2O {'': True, 'name': 'n2ohts', 'dirname': 'n2ohts', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 2, 'spin': 1}
# 84 HO {'': True, 'name': 'oh', 'dirname': 'oh', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 2, 'spin': 1}
# 85 HO {'': True, 'name': 'oh-', 'dirname': 'oh-', 'dataset': 'bh76', 'charge': -1, 'multiplicity': 1, 'spin': 0}

# %% [markdown]
# For N2O+H -> OH+N2, the reaction is first in the dataset. -H - N2O + n2ohts = 17.7 kcal/mol
# For OH + CL -> O + HCl, the reaction is 66th: -OH - CL + RKT17 = 9.9 kcal/mol.

# %%
#-H - N2O -> n2ohts, -OH - CL -> rkt17
bhinds = [63, 82, 83, 84, 49, 33]

# %%
g2val = [g297[i] for i in g2inds]
bhval = [bh76[i] for i in bhinds]
bhvalr = [0, 0, 17.7/Hart_to_kcalmol, 0, 0, 9.9/Hart_to_kcalmol]

# %%
#H
bhval[0].info['product'] = 'n2ohts'
bhval[0].info['enmult'] = -1
#N2O
bhval[1].info['product'] = 'n2ohts'
bhval[1].info['enmult'] = -1
#n2ohts
bhval[2].info['product'] = 'n2ohts'
bhval[2].info['enmult'] = 1
bhval[2].info['bh_ref'] = 17.7/Hart_to_kcalmol

#OH
bhval[3].info['product'] = 'RKT17'
bhval[3].info['enmult'] = -1
#CL
bhval[4].info['product'] = 'RKT17'
bhval[4].info['enmult'] = -1
#RKT17
bhval[5].info['product']='RKT17'
bhval[5].info['enmult'] = 1
bhval[5].info['bh_ref'] = 9.9/Hart_to_kcalmol

# %%
val = g2val+bhval
write('/home/awills/Documents/Research/dpyscfl/data/validation/val.traj', val)

# %%
tval = read('/home/awills/Documents/Research/dpyscfl/data/validation/val.traj', ':')
tvalc = read('/home/awills/Documents/Research/swxcd/aegis/validation/results.traj', ':')
for idx, at in enumerate(tval):
    print(idx, at, at.info)
    try:
        print(at.info['energy'])
    except:
        at.info['energy'] = tvalc[idx].calc.results['energy']
        print("No energy in info dict.")
write('/home/awills/Documents/Research/swxcd/aegis/validation/val_c.traj', val)
# Out:
# 0 Atoms(symbols='S2', pbc=False, calculator=SinglePointCalculator(...)) {'S2': True, 'energy': -795.7439189734063, 'atomization': 0.1652790172181213, 'atomization_ev': 4.497471139250339, 'atomization_H': 0.1652790172181213, 'openshell': True, 'name': 'Disulfur'}
# -795.7439189734063
# 1 Atoms(symbols='C2H2', pbc=False, calculator=SinglePointCalculator(...)) {'C2H2': True, 'energy': -77.23364708420903, 'atomization': 0.6458922998762915, 'atomization_ev': 17.575624702100136, 'atomization_H': 0.6458922998762915, 'openshell': False, 'name': 'Acetylene'}
# -77.23364708420903
# 2 Atoms(symbols='BeH', pbc=False, calculator=SinglePointCalculator(...)) {'BeH': True, 'energy': -15.213086658834586, 'atomization': 0.08093697552392216, 'atomization_ev': 2.2024072846262093, 'atomization_H': 0.08093697552392216, 'openshell': True, 'name': 'Beryllium monohydride'}
# -15.213086658834586
# 3 Atoms(symbols='NO2', pbc=False, calculator=SinglePointCalculator(...)) {'NO2': True, 'energy': -204.87297985889361, 'atomization': 0.36339749810529004, 'atomization_ev': 9.888549601232311, 'atomization_H': 0.36339749810529004, 'openshell': True, 'name': 'Nitrogen dioxide'}
# -204.87297985889361
# 4 Atoms(symbols='CH4', pbc=False, calculator=SinglePointCalculator(...)) {'CH4': True, 'energy': -40.46144804424925, 'atomization': 0.6695182791315805, 'atomization_ev': 18.218520343819495, 'atomization_H': 0.6695182791315805, 'openshell': False, 'name': 'Methane'}
# -40.46144804424925
# 5 Atoms(symbols='PF3', pbc=False, calculator=SinglePointCalculator(...)) {'PF3': True, 'energy': -640.4601109820627, 'atomization': 0.5830966332662726, 'atomization_ev': 15.866867577317441, 'atomization_H': 0.5830966332662726, 'openshell': False, 'name': 'Phosphorus trifluoride'}
# -640.4601109820627
# 6 Atoms(symbols='CH2', pbc=False, calculator=SinglePointCalculator(...)) {'CH2': True, 'energy': -39.08309334882895, 'atomization': 0.28849746875574045, 'atomization_ev': 7.850415989365281, 'atomization_H': 0.28849746875574045, 'openshell': True, 'name': 'Singlet carbene'}
# -39.08309334882895
# 7 Atoms(symbols='CO2HCH3', pbc=False, calculator=SinglePointCalculator(...)) {'C2H4O2': True, 'energy': -228.8242969783602, 'atomization': 1.2540889175521006, 'atomization_ev': 34.125497644391075, 'atomization_H': 1.2540889175521006, 'openshell': False, 'name': 'Methyl formate'}
# -228.8242969783602
# 8 Atoms(symbols='H', pbc=False) {'': True, 'name': 'h', 'dirname': 'h', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 2, 'spin': 1, 'product': 'n2ohts', 'enmult': -1}
# No energy in info dict.
# 9 Atoms(symbols='N2O', pbc=False) {'': True, 'name': 'n2o', 'dirname': 'n2o', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 1, 'spin': 0, 'product': 'n2ohts', 'enmult': -1}
# No energy in info dict.
# 10 Atoms(symbols='HON2', pbc=False) {'': True, 'name': 'n2ohts', 'dirname': 'n2ohts', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 2, 'spin': 1, 'product': 'n2ohts', 'enmult': 1, 'bh_ref': 0.028206745454023522}
# No energy in info dict.
# 11 Atoms(symbols='OH', pbc=False) {'': True, 'name': 'oh', 'dirname': 'oh', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 2, 'spin': 1, 'product': 'RKT17', 'enmult': -1}
# No energy in info dict.
# 12 Atoms(symbols='Cl', pbc=False) {'': True, 'name': 'cl', 'dirname': 'cl', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 2, 'spin': 1, 'product': 'RKT17', 'enmult': -1}
# No energy in info dict.
# 13 Atoms(symbols='ClHO', pbc=False) {'': True, 'name': 'RKT17', 'dirname': 'RKT17', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 3, 'spin': 2, 'product': 'RKT17', 'enmult': 1, 'bh_ref': 0.01577665423699621}
# No energy in info dict.

# %%
for idx, at in enumerate(tval):
    print(idx, at, at.info)
    try:
        print(at.info['energy'])
    except:
        at.info['energy'] = tvalc[idx].calc.results['energy']
        print("No energy in info dict.")
    try:
        print(at.info['atomization'])
    except:
        at.info['atomization'] = np.nan
write('/home/awills/Documents/Research/swxcd/aegis/validation/val_c.traj', tval)
# Out:
# 0 Atoms(symbols='S2', pbc=False, calculator=SinglePointCalculator(...)) {'S2': True, 'energy': -795.7439189734063, 'atomization': 0.1652790172181213, 'atomization_ev': 4.497471139250339, 'atomization_H': 0.1652790172181213, 'openshell': True, 'name': 'Disulfur'}
# -795.7439189734063
# 0.1652790172181213
# 1 Atoms(symbols='C2H2', pbc=False, calculator=SinglePointCalculator(...)) {'C2H2': True, 'energy': -77.23364708420903, 'atomization': 0.6458922998762915, 'atomization_ev': 17.575624702100136, 'atomization_H': 0.6458922998762915, 'openshell': False, 'name': 'Acetylene'}
# -77.23364708420903
# 0.6458922998762915
# 2 Atoms(symbols='BeH', pbc=False, calculator=SinglePointCalculator(...)) {'BeH': True, 'energy': -15.213086658834586, 'atomization': 0.08093697552392216, 'atomization_ev': 2.2024072846262093, 'atomization_H': 0.08093697552392216, 'openshell': True, 'name': 'Beryllium monohydride'}
# -15.213086658834586
# 0.08093697552392216
# 3 Atoms(symbols='NO2', pbc=False, calculator=SinglePointCalculator(...)) {'NO2': True, 'energy': -204.87297985889361, 'atomization': 0.36339749810529004, 'atomization_ev': 9.888549601232311, 'atomization_H': 0.36339749810529004, 'openshell': True, 'name': 'Nitrogen dioxide'}
# -204.87297985889361
# 0.36339749810529004
# 4 Atoms(symbols='CH4', pbc=False, calculator=SinglePointCalculator(...)) {'CH4': True, 'energy': -40.46144804424925, 'atomization': 0.6695182791315805, 'atomization_ev': 18.218520343819495, 'atomization_H': 0.6695182791315805, 'openshell': False, 'name': 'Methane'}
# -40.46144804424925
# 0.6695182791315805
# 5 Atoms(symbols='PF3', pbc=False, calculator=SinglePointCalculator(...)) {'PF3': True, 'energy': -640.4601109820627, 'atomization': 0.5830966332662726, 'atomization_ev': 15.866867577317441, 'atomization_H': 0.5830966332662726, 'openshell': False, 'name': 'Phosphorus trifluoride'}
# -640.4601109820627
# 0.5830966332662726
# 6 Atoms(symbols='CH2', pbc=False, calculator=SinglePointCalculator(...)) {'CH2': True, 'energy': -39.08309334882895, 'atomization': 0.28849746875574045, 'atomization_ev': 7.850415989365281, 'atomization_H': 0.28849746875574045, 'openshell': True, 'name': 'Singlet carbene'}
# -39.08309334882895
# 0.28849746875574045
# 7 Atoms(symbols='CO2HCH3', pbc=False, calculator=SinglePointCalculator(...)) {'C2H4O2': True, 'energy': -228.8242969783602, 'atomization': 1.2540889175521006, 'atomization_ev': 34.125497644391075, 'atomization_H': 1.2540889175521006, 'openshell': False, 'name': 'Methyl formate'}
# -228.8242969783602
# 1.2540889175521006
# 8 Atoms(symbols='H', pbc=False) {'': True, 'name': 'h', 'dirname': 'h', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 2, 'spin': 1, 'product': 'n2ohts', 'enmult': -1, 'energy': -0.49981791563041966}
# -0.49981791563041966
# 9 Atoms(symbols='N2O', pbc=False) {'': True, 'name': 'n2o', 'dirname': 'n2o', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 1, 'spin': 0, 'product': 'n2ohts', 'enmult': -1, 'energy': -184.47881913926975}
# -184.47881913926975
# 10 Atoms(symbols='HON2', pbc=False) {'': True, 'name': 'n2ohts', 'dirname': 'n2ohts', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 2, 'spin': 1, 'product': 'n2ohts', 'enmult': 1, 'bh_ref': 0.028206745454023522, 'energy': -184.94901512929493}
# -184.94901512929493
# 11 Atoms(symbols='OH', pbc=False) {'': True, 'name': 'oh', 'dirname': 'oh', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 2, 'spin': 1, 'product': 'RKT17', 'enmult': -1, 'energy': -75.6622671033986}
# -75.6622671033986
# 12 Atoms(symbols='Cl', pbc=False) {'': True, 'name': 'cl', 'dirname': 'cl', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 2, 'spin': 1, 'product': 'RKT17', 'enmult': -1, 'energy': -459.75483999758393}
# -459.75483999758393
# 13 Atoms(symbols='ClHO', pbc=False) {'': True, 'name': 'RKT17', 'dirname': 'RKT17', 'dataset': 'bh76', 'charge': 0, 'multiplicity': 3, 'spin': 2, 'product': 'RKT17', 'enmult': 1, 'bh_ref': 0.01577665423699621, 'energy': -535.4004261314922}
# -535.4004261314922
